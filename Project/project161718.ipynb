# %%
import pandas as pd
import numpy as np

# %%
naver = pd.read_csv('C:\\dev_python\\project\\data_final\\naver_final.csv', encoding = "CP949")
naver
# Out:
#              날짜       감기
# 0    2016-01-01  4.27966
# 1    2016-01-02  4.90676
# 2    2016-01-03  5.47383
# 3    2016-01-04  6.40781
# 4    2016-01-05  6.32109
# ..          ...      ...
# 907  2018-06-26  3.91941
# 908  2018-06-27  3.76263
# 909  2018-06-28  3.50245
# 910  2018-06-29  3.23226
# 911  2018-06-30  3.15220
#
# [912 rows x 2 columns]

# %%
list_date = naver.날짜.str.split('-')
list_date
# Out:
# 0      [2016, 01, 01]
# 1      [2016, 01, 02]
# 2      [2016, 01, 03]
# 3      [2016, 01, 04]
# 4      [2016, 01, 05]
#             ...
# 907    [2018, 06, 26]
# 908    [2018, 06, 27]
# 909    [2018, 06, 28]
# 910    [2018, 06, 29]
# 911    [2018, 06, 30]
# Name: 날짜, Length: 912, dtype: object

# %%
naver['y'] = list_date.str.get(0)
naver['m'] = list_date.str.get(1)
naver['d'] = list_date.str.get(2)

naver
# Out:
#              날짜       감기     y   m   d
# 0    2016-01-01  4.27966  2016  01  01
# 1    2016-01-02  4.90676  2016  01  02
# 2    2016-01-03  5.47383  2016  01  03
# 3    2016-01-04  6.40781  2016  01  04
# 4    2016-01-05  6.32109  2016  01  05
# ..          ...      ...   ...  ..  ..
# 907  2018-06-26  3.91941  2018  06  26
# 908  2018-06-27  3.76263  2018  06  27
# 909  2018-06-28  3.50245  2018  06  28
# 910  2018-06-29  3.23226  2018  06  29
# 911  2018-06-30  3.15220  2018  06  30
#
# [912 rows x 5 columns]

# %%
naver['date'] = naver['y'] + naver['m'] + naver['d']
naver
# Out:
#              날짜       감기     y   m   d      date
# 0    2016-01-01  4.27966  2016  01  01  20160101
# 1    2016-01-02  4.90676  2016  01  02  20160102
# 2    2016-01-03  5.47383  2016  01  03  20160103
# 3    2016-01-04  6.40781  2016  01  04  20160104
# 4    2016-01-05  6.32109  2016  01  05  20160105
# ..          ...      ...   ...  ..  ..       ...
# 907  2018-06-26  3.91941  2018  06  26  20180626
# 908  2018-06-27  3.76263  2018  06  27  20180627
# 909  2018-06-28  3.50245  2018  06  28  20180628
# 910  2018-06-29  3.23226  2018  06  29  20180629
# 911  2018-06-30  3.15220  2018  06  30  20180630
#
# [912 rows x 6 columns]

# %%
naver = naver.loc[:,["감기","date"]]
naver
# Out:
#           감기      date
# 0    4.27966  20160101
# 1    4.90676  20160102
# 2    5.47383  20160103
# 3    6.40781  20160104
# 4    6.32109  20160105
# ..       ...       ...
# 907  3.91941  20180626
# 908  3.76263  20180627
# 909  3.50245  20180628
# 910  3.23226  20180629
# 911  3.15220  20180630
#
# [912 rows x 2 columns]

# %%
naver2 = naver[naver["date"] >= '20160501']
naver2
# Out:
#           감기      date
# 121  3.90606  20160501
# 122  4.79001  20160502
# 123  4.58320  20160503
# 124  4.21294  20160504
# 125  3.73261  20160505
# ..       ...       ...
# 907  3.91941  20180626
# 908  3.76263  20180627
# 909  3.50245  20180628
# 910  3.23226  20180629
# 911  3.15220  20180630
#
# [791 rows x 2 columns]

# %%
naver2["date"].dtype
# Out:
# dtype('O')

# %%
mos = pd.read_csv('C:\dev_python\project\data_final\mosquito_final.csv', encoding = "CP949")
mos = mos.iloc[:, 1:]
mos
# Out:
#       모기지수 발생일   모기지수
# 0     20200129    5.5
# 1     20200128    5.5
# 2     20200127    5.5
# 3     20200126    5.5
# 4     20200125    5.5
# ...        ...    ...
# 1351  20160505  243.8
# 1352  20160504  256.2
# 1353  20160503  304.0
# 1354  20160502  273.5
# 1355  20160501  254.4
#
# [1356 rows x 2 columns]

# %%
mos["모기지수 발생일"].dtype
# Out:
# dtype('int64')

# %%
mos["모기지수 발생일"].astype(str)
# Out:
# 0       20200129
# 1       20200128
# 2       20200127
# 3       20200126
# 4       20200125
#           ...
# 1351    20160505
# 1352    20160504
# 1353    20160503
# 1354    20160502
# 1355    20160501
# Name: 모기지수 발생일, Length: 1356, dtype: object

# %%
mos["모기지수 발생일"] = mos["모기지수 발생일"].astype(str)

# %%
mos2 = mos[mos["모기지수 발생일"] <= '20180630']
mos2
# Out:
#       모기지수 발생일    모기지수
# 541   20180630   869.9
# 542   20180629   817.0
# 543   20180628   766.3
# 544   20180627   974.7
# 545   20180626  1000.0
# ...        ...     ...
# 1351  20160505   243.8
# 1352  20160504   256.2
# 1353  20160503   304.0
# 1354  20160502   273.5
# 1355  20160501   254.4
#
# [815 rows x 2 columns]

# %%
mn = mos2.merge(naver2, left_on=['모기지수 발생일'], right_on=['date'], how = 'left') 
mn = mn.drop(['모기지수 발생일'], axis=1)
mn
# Out:
#        모기지수       감기      date
# 0     869.9  3.15220  20180630
# 1     817.0  3.23226  20180629
# 2     766.3  3.50245  20180628
# 3     974.7  3.76263  20180627
# 4    1000.0  3.91941  20180626
# ..      ...      ...       ...
# 810   243.8  3.73261  20160505
# 811   256.2  4.21294  20160504
# 812   304.0  4.58320  20160503
# 813   273.5  4.79001  20160502
# 814   254.4  3.90606  20160501
#
# [815 rows x 3 columns]

# %%
mn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 815 entries, 0 to 814
# Data columns (total 3 columns):
# 모기지수    815 non-null float64
# 감기      815 non-null float64
# date    815 non-null object
# dtypes: float64(2), object(1)
# memory usage: 25.5+ KB

# %%
naver3 = naver2.drop_duplicates('date')
naver3
# Out:
#           감기      date
# 121  3.90606  20160501
# 122  4.79001  20160502
# 123  4.58320  20160503
# 124  4.21294  20160504
# 125  3.73261  20160505
# ..       ...       ...
# 907  3.91941  20180626
# 908  3.76263  20180627
# 909  3.50245  20180628
# 910  3.23226  20180629
# 911  3.15220  20180630
#
# [791 rows x 2 columns]

# %%
mos3 = mos2.drop_duplicates('모기지수 발생일')
mos3
# Out:
#       모기지수 발생일    모기지수
# 541   20180630   869.9
# 542   20180629   817.0
# 543   20180628   766.3
# 544   20180627   974.7
# 545   20180626  1000.0
# ...        ...     ...
# 1351  20160505   243.8
# 1352  20160504   256.2
# 1353  20160503   304.0
# 1354  20160502   273.5
# 1355  20160501   254.4
#
# [785 rows x 2 columns]

# %%
mn = naver3.merge(mos3, left_on=['date'], right_on=['모기지수 발생일'], how = 'left') 
mn = mn.drop(['모기지수 발생일'], axis=1)
mn
# Out:
#           감기      date    모기지수
# 0    3.90606  20160501   254.4
# 1    4.79001  20160502   273.5
# 2    4.58320  20160503   304.0
# 3    4.21294  20160504   256.2
# 4    3.73261  20160505   243.8
# ..       ...       ...     ...
# 786  3.91941  20180626  1000.0
# 787  3.76263  20180627   974.7
# 788  3.50245  20180628   766.3
# 789  3.23226  20180629   817.0
# 790  3.15220  20180630   869.9
#
# [791 rows x 3 columns]

# %%
mn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 791 entries, 0 to 790
# Data columns (total 3 columns):
# 감기      791 non-null float64
# date    791 non-null object
# 모기지수    785 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 24.7+ KB

# %%
mn.drop_duplicates('date')
# Out:
#           감기      date    모기지수
# 0    3.90606  20160501   254.4
# 1    4.79001  20160502   273.5
# 2    4.58320  20160503   304.0
# 3    4.21294  20160504   256.2
# 4    3.73261  20160505   243.8
# ..       ...       ...     ...
# 786  3.91941  20180626  1000.0
# 787  3.76263  20180627   974.7
# 788  3.50245  20180628   766.3
# 789  3.23226  20180629   817.0
# 790  3.15220  20180630   869.9
#
# [791 rows x 3 columns]

# %%
mn.columns = ["검색량", "date1", "모기지수"]

# %%
mn
# Out:
#          검색량     date1    모기지수
# 0    3.90606  20160501   254.4
# 1    4.79001  20160502   273.5
# 2    4.58320  20160503   304.0
# 3    4.21294  20160504   256.2
# 4    3.73261  20160505   243.8
# ..       ...       ...     ...
# 786  3.91941  20180626  1000.0
# 787  3.76263  20180627   974.7
# 788  3.50245  20180628   766.3
# 789  3.23226  20180629   817.0
# 790  3.15220  20180630   869.9
#
# [791 rows x 3 columns]

# %%
mn.to_csv('C:\\dev_python\\project\\data_final\\naver_mos_1678.csv', encoding = "CP949", index = False)

# %%
air = pd.read_csv('C:\dev_python\project\data_final2\\air_20145678.csv', encoding = "CP949")
air
# Out:
#        시군구지역코드 시군구명      측정일시  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# 0        11110  종로구  20140101      0.036000   0.007000      0.400000
# 1        11140   중구  20140101      0.036000   0.012000      0.600000
# 2        11170  용산구  20140101      0.033000   0.010000      0.500000
# 3        11200  성동구  20140101      0.032000   0.009000      0.400000
# 4        11215  광진구  20140101      0.031000   0.012000      0.800000
# ...        ...  ...       ...           ...        ...           ...
# 43727    11740  강동구  20181015      0.038333   0.022083      0.670833
# 43728    11740  강동구  20181016      0.039208   0.014417      0.654167
# 43729    11740  강동구  20181017      0.038792   0.011583      0.566667
# 43730    11740  강동구  20181018      0.024417   0.012875      0.387500
# 43731    11740  강동구  20181019      0.017500   0.017000      0.300000
#
#        아황산가스.ppm.   미세먼지.....  초미세먼지.....
# 0        0.007000  112.000000   21.000000
# 1        0.011000  117.000000   27.000000
# ...

# %%
air_16 = air[(air["측정일시"] >= 20160501) & (air["측정일시"] <= 20180630)]
air_16
# Out:
#        시군구지역코드 시군구명      측정일시  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# 21182    11110  종로구  20160501      0.026000   0.033000      0.400000
# 21183    11140   중구  20160501      0.032000   0.045000      0.600000
# 21184    11170  용산구  20160501      0.026000   0.047000      0.400000
# 21185    11200  성동구  20160501      0.033000   0.039000      0.600000
# 21186    11215  광진구  20160501      0.025000   0.053000      0.600000
# ...        ...  ...       ...           ...        ...           ...
# 43616    11740  강동구  20180626      0.021625   0.028375      0.475000
# 43617    11740  강동구  20180627      0.019875   0.030333      0.479167
# 43618    11740  강동구  20180628      0.023042   0.019750      0.416667
# 43619    11740  강동구  20180629      0.026750   0.031292      0.475000
# 43620    11740  강동구  20180630      0.025208   0.019792      0.475000
#
#        아황산가스.ppm.  미세먼지.....  초미세먼지.....
# 21182    0.005000  43.000000   20.000000
# 21183    0.005000  45.000000   20.000000
# ...

# %%
weather = pd.read_csv('C:\dev_python\project\data_final2\seoul_w_real_final.csv', encoding = "CP949")
weather
# Out:
#        일강수량(mm)        일시  최고기온(°C)  최대 순간 풍속 풍향(deg)  최대 순간 풍속(m/s)  \
# 0           0.0  20170101       7.0              73.1            3.3
# 1           0.0  20170102       9.4             196.9            5.8
# 2           0.0  20170103       7.2             227.8            5.6
# 3           0.0  20170104       9.3             315.0            6.5
# 4           0.0  20170105       7.8              67.5            6.5
# ...         ...       ...       ...               ...            ...
# 45641       0.0  20141227       3.7               NaN            4.5
# 45642       0.0  20141228       2.0               NaN            4.8
# 45643       0.0  20141229       6.4               NaN            5.6
# 45644       0.0  20141230       6.2               NaN            8.5
# 45645       0.0  20141231       2.8               NaN           12.9
#
#        최저기온 시각(hhmi)  최저기온(°C)  평균 풍속(m/s)  평균기온(°C) 지점.1  자치구코드
# 0              626.0      -0.4         1.3       3.5   강남  11680
# ...

# %%
weather_16 = weather[(weather["일시"] >= 20160501) & (weather["일시"] <= 20180630)]
weather_16
# Out:
#        일강수량(mm)        일시  최고기온(°C)  최대 순간 풍속 풍향(deg)  최대 순간 풍속(m/s)  \
# 0           0.0  20170101       7.0              73.1            3.3
# 1           0.0  20170102       9.4             196.9            5.8
# 2           0.0  20170103       7.2             227.8            5.6
# 3           0.0  20170104       9.3             315.0            6.5
# 4           0.0  20170105       7.8              67.5            6.5
# ...         ...       ...       ...               ...            ...
# 44911       0.0  20161227       2.8             255.9            7.6
# 44912       0.0  20161228       2.4             230.6            6.1
# 44913       0.0  20161229      -0.4             292.5            8.3
# 44914       0.0  20161230       1.2             345.9            5.2
# 44915       0.0  20161231       5.5             101.3            4.5
#
#        최저기온 시각(hhmi)  최저기온(°C)  평균 풍속(m/s)  평균기온(°C) 지점.1  자치구코드
# 0              626.0      -0.4         1.3       3.5   강남  11680
# ...

# %%
cold = pd.read_csv('C:\dev_python\project\data_final\cold_final.csv', encoding = "CP949")
cold
# Out:
#              날짜  시군구지역코드  발생건수(건) 시군구명
# 0      20140101    11110       53  종로구
# 1      20140102    11110     1408  종로구
# 2      20140103    11110     1129  종로구
# 3      20140104    11110      890  종로구
# 4      20140105    11110      134  종로구
# ...         ...      ...      ...  ...
# 41045  20180626    11740     1796  강동구
# 41046  20180627    11740     2135  강동구
# 41047  20180628    11740     2025  강동구
# 41048  20180629    11740     2360  강동구
# 41049  20180630    11740     1985  강동구
#
# [41050 rows x 4 columns]

# %%
cold_16 = cold[(cold["날짜"] >= 20160501) & (cold["날짜"] <= 20180630)]
cold_16
# Out:
#              날짜  시군구지역코드  발생건수(건) 시군구명
# 851    20160501    11110      132  종로구
# 852    20160502    11110     1535  종로구
# 853    20160503    11110      878  종로구
# 854    20160504    11110     1232  종로구
# 855    20160505    11110      136  종로구
# ...         ...      ...      ...  ...
# 41045  20180626    11740     1796  강동구
# 41046  20180627    11740     2135  강동구
# 41047  20180628    11740     2025  강동구
# 41048  20180629    11740     2360  강동구
# 41049  20180630    11740     1985  강동구
#
# [19775 rows x 4 columns]

# %%
cold_16.columns = ["date", "gu_code", "target", "gu_name"]
cold_16
# Out:
#            date  gu_code  target gu_name
# 851    20160501    11110     132     종로구
# 852    20160502    11110    1535     종로구
# 853    20160503    11110     878     종로구
# 854    20160504    11110    1232     종로구
# 855    20160505    11110     136     종로구
# ...         ...      ...     ...     ...
# 41045  20180626    11740    1796     강동구
# 41046  20180627    11740    2135     강동구
# 41047  20180628    11740    2025     강동구
# 41048  20180629    11740    2360     강동구
# 41049  20180630    11740    1985     강동구
#
# [19775 rows x 4 columns]

# %%
cw = cold_16.merge(weather_16, left_on=['date', 'gu_code'], right_on=['일시', '자치구코드'], how = 'left') 
cw = cw.drop(['일시', '자치구코드', '지점.1'], axis=1)
cw
# Out:
#            date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 0      20160501    11110     132     종로구       0.0      27.1
# 1      20160502    11110    1535     종로구      20.5      28.7
# 2      20160503    11110     878     종로구      29.0      18.9
# 3      20160504    11110    1232     종로구       0.0      21.1
# 4      20160505    11110     136     종로구       5.5      26.6
# ...         ...      ...     ...     ...       ...       ...
# 19770  20180626    11740    1796     강동구      76.0      26.9
# 19771  20180627    11740    2135     강동구       1.5      26.0
# 19772  20180628    11740    2025     강동구      15.0      27.9
# 19773  20180629    11740    2360     강동구       1.0      29.7
# 19774  20180630    11740    1985     강동구      24.0      28.7
#
#        최대 순간 풍속 풍향(deg)  최대 순간 풍속(m/s)  최저기온 시각(hhmi)  최저기온(°C)  평균 풍속(m/s)  \
# 0                 194.1            9.6          521.0      14.0         1.9
# 1                 182.8           10.8          615.0      17.6         2.1
# ...

# %%
cwa = cw.merge(air_16, left_on=['date', 'gu_code'], right_on=['측정일시', '시군구지역코드'], how = 'left') 
cwa = cwa.drop(['측정일시', '시군구지역코드' , '시군구명'], axis=1)
cwa
# Out:
#            date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 0      20160501    11110     132     종로구       0.0      27.1
# 1      20160502    11110    1535     종로구      20.5      28.7
# 2      20160503    11110     878     종로구      29.0      18.9
# 3      20160504    11110    1232     종로구       0.0      21.1
# 4      20160505    11110     136     종로구       5.5      26.6
# ...         ...      ...     ...     ...       ...       ...
# 19770  20180626    11740    1796     강동구      76.0      26.9
# 19771  20180627    11740    2135     강동구       1.5      26.0
# 19772  20180628    11740    2025     강동구      15.0      27.9
# 19773  20180629    11740    2360     강동구       1.0      29.7
# 19774  20180630    11740    1985     강동구      24.0      28.7
#
#        최대 순간 풍속 풍향(deg)  최대 순간 풍속(m/s)  최저기온 시각(hhmi)  최저기온(°C)  평균 풍속(m/s)  \
# 0                 194.1            9.6          521.0      14.0         1.9
# 1                 182.8           10.8          615.0      17.6         2.1
# ...

# %%
cwa["date"].dtype
# Out:
# dtype('int64')

# %%
mn["date1"].dtype
# Out:
# dtype('O')

# %%
mn["date1"] = mn["date1"].astype(int)
mn["date1"].dtype
# Out:
# dtype('int32')

# %%
cwamn = cwa.merge(mn, left_on=['date'], right_on=['date1'], how = 'left') 
cwamn = cwamn.drop(['date1'], axis=1)
cwamn
# Out:
#            date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 0      20160501    11110     132     종로구       0.0      27.1
# 1      20160502    11110    1535     종로구      20.5      28.7
# 2      20160503    11110     878     종로구      29.0      18.9
# 3      20160504    11110    1232     종로구       0.0      21.1
# 4      20160505    11110     136     종로구       5.5      26.6
# ...         ...      ...     ...     ...       ...       ...
# 19770  20180626    11740    1796     강동구      76.0      26.9
# 19771  20180627    11740    2135     강동구       1.5      26.0
# 19772  20180628    11740    2025     강동구      15.0      27.9
# 19773  20180629    11740    2360     강동구       1.0      29.7
# 19774  20180630    11740    1985     강동구      24.0      28.7
#
#        최대 순간 풍속 풍향(deg)  최대 순간 풍속(m/s)  최저기온 시각(hhmi)  최저기온(°C)  평균 풍속(m/s)  \
# 0                 194.1            9.6          521.0      14.0         1.9
# 1                 182.8           10.8          615.0      17.6         2.1
# ...

# %%
cwamn.drop_duplicates(['date', 'gu_code'])
# Out:
#            date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 0      20160501    11110     132     종로구       0.0      27.1
# 1      20160502    11110    1535     종로구      20.5      28.7
# 2      20160503    11110     878     종로구      29.0      18.9
# 3      20160504    11110    1232     종로구       0.0      21.1
# 4      20160505    11110     136     종로구       5.5      26.6
# ...         ...      ...     ...     ...       ...       ...
# 19770  20180626    11740    1796     강동구      76.0      26.9
# 19771  20180627    11740    2135     강동구       1.5      26.0
# 19772  20180628    11740    2025     강동구      15.0      27.9
# 19773  20180629    11740    2360     강동구       1.0      29.7
# 19774  20180630    11740    1985     강동구      24.0      28.7
#
#        최대 순간 풍속 풍향(deg)  최대 순간 풍속(m/s)  최저기온 시각(hhmi)  최저기온(°C)  평균 풍속(m/s)  \
# 0                 194.1            9.6          521.0      14.0         1.9
# 1                 182.8           10.8          615.0      17.6         2.1
# ...

# %%
cwamn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19775 entries, 0 to 19774
# Data columns (total 20 columns):
# date                19775 non-null int64
# gu_code             19775 non-null int64
# target              19775 non-null int64
# gu_name             19775 non-null object
# 일강수량(mm)            19767 non-null float64
# 최고기온(°C)            19696 non-null float64
# 최대 순간 풍속 풍향(deg)    19430 non-null float64
# 최대 순간 풍속(m/s)       19440 non-null float64
# 최저기온 시각(hhmi)       19696 non-null float64
# 최저기온(°C)            19696 non-null float64
# 평균 풍속(m/s)          19695 non-null float64
# 평균기온(°C)            19689 non-null float64
# 이산화질소농도.ppm.        19775 non-null float64
# 오존농도.ppm.           19775 non-null float64
# 이산화탄소농도.ppm.        19775 non-null float64
# 아황산가스.ppm.          19775 non-null float64
# 미세먼지.....           19775 non-null float64
# 초미세먼지.....          19775 non-null float64
# 검색량                 19775 non-null float64
# ...

# %%
cwamn.to_csv("C:\dev_python\project\data_final2\data_201678.csv", encoding = 'cp949', index = False)

# %%
df = pd.read_csv('C:\\dev_python\\project\\data_final2\\Data_good.csv', encoding = "CP949")
df
# Out:
#            date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  최저기온(°C)  \
# 0      20160501    11110     132     종로구       0.0      27.1      14.0
# 1      20160501    11140     112      중구       0.0      27.9      13.8
# 2      20160501    11170     195     용산구       0.0      25.8      14.1
# 3      20160501    11200     328     성동구       0.0      26.1      14.0
# 4      20160501    11215     318     광진구       0.0      26.3      13.1
# ...         ...      ...     ...     ...       ...       ...       ...
# 19770  20180630    11620    1978     관악구       0.5      27.7      18.9
# 19771  20180630    11650    1948     서초구       0.5      30.1      21.3
# 19772  20180630    11680    2324     강남구       3.5      29.6      22.8
# 19773  20180630    11710    3118     송파구       3.0      29.4      22.7
# 19774  20180630    11740    1985     강동구      24.0      28.7      21.4
#
#        평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# ...

# %%
df_fillna = df.fillna(method='ffill')
df_fillna
# Out:
#            date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  최저기온(°C)  \
# 22     20160501    11680     471     강남구       0.0      26.2      14.5
# 24     20160501    11740     465     강동구       0.0      26.2      11.6
# 8      20160501    11305     434     강북구       0.0      27.2      13.5
# 15     20160501    11500    1041     강서구       0.0      25.2      15.4
# 20     20160501    11620     415     관악구       0.0      25.6      13.4
# ...         ...      ...     ...     ...       ...       ...       ...
# 19752  20180630    11170     863     용산구      20.0      29.6      22.5
# 19761  20180630    11380    2028     은평구      23.5      27.6      18.4
# 19750  20180630    11110     508     종로구      14.0      29.9      22.3
# 19751  20180630    11140     492      중구       5.0      28.7      20.9
# 19756  20180630    11260    1787     중랑구      14.0      29.9      22.3
#
#        평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# ...

# %%
df_fillna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19775 entries, 22 to 19756
# Data columns (total 17 columns):
# date            19775 non-null int64
# gu_code         19775 non-null int64
# target          19775 non-null int64
# gu_name         19775 non-null object
# 일강수량(mm)        19775 non-null float64
# 최고기온(°C)        19775 non-null float64
# 최저기온(°C)        19775 non-null float64
# 평균 풍속(m/s)      19775 non-null float64
# 평균기온(°C)        19775 non-null float64
# 이산화질소농도.ppm.    19775 non-null float64
# 오존농도.ppm.       19775 non-null float64
# 이산화탄소농도.ppm.    19775 non-null float64
# 아황산가스.ppm.      19775 non-null float64
# 미세먼지.....       19775 non-null float64
# 초미세먼지.....      19775 non-null float64
# 검색량             19775 non-null float64
# 모기지수            19775 non-null float64
# dtypes: float64(13), int64(3), object(1)
# memory usage: 2.7+ MB

# %%
df_fillna.to_csv("C:\dev_python\project\data_final2\data_good_good.csv", encoding = 'cp949', index = False)

# %%
df = pd.read_csv('C:\\dev_python\\project\\data_final2\\Data_month.csv', encoding = "CP949")
df
# Out:
#        Unnamed: 0      date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 0               0  20160501    11680     471     강남구       0.0      26.2
# 1               1  20160501    11740     465     강동구       0.0      26.2
# 2               2  20160501    11305     434     강북구       0.0      27.2
# 3               3  20160501    11500    1041     강서구       0.0      25.2
# 4               4  20160501    11620     415     관악구       0.0      25.6
# ...           ...       ...      ...     ...     ...       ...       ...
# 19770       19770  20180630    11170     863     용산구      20.0      29.6
# 19771       19771  20180630    11380    2028     은평구      23.5      27.6
# 19772       19772  20180630    11110     508     종로구      14.0      29.9
# 19773       19773  20180630    11140     492      중구       5.0      28.7
# 19774       19774  20180630    11260    1787     중랑구      14.0      29.9
#
#        최저기온(°C)  평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# ...

# %%
df["date"].dtype
# Out:
# dtype('int64')

# %%
df["date"] = df["date"].astype(str)
df["date"].dtype
# Out:
# dtype('O')

# %%
import datetime

df["date"] = pd.to_datetime(df["date"])
df["요일"] = df["date"].dt.dayofweek
df
# Out:
#        Unnamed: 0       date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 0               0 2016-05-01    11680     471     강남구       0.0      26.2
# 1               1 2016-05-01    11740     465     강동구       0.0      26.2
# 2               2 2016-05-01    11305     434     강북구       0.0      27.2
# 3               3 2016-05-01    11500    1041     강서구       0.0      25.2
# 4               4 2016-05-01    11620     415     관악구       0.0      25.6
# ...           ...        ...      ...     ...     ...       ...       ...
# 19770       19770 2018-06-30    11170     863     용산구      20.0      29.6
# 19771       19771 2018-06-30    11380    2028     은평구      23.5      27.6
# 19772       19772 2018-06-30    11110     508     종로구      14.0      29.9
# 19773       19773 2018-06-30    11140     492      중구       5.0      28.7
# 19774       19774 2018-06-30    11260    1787     중랑구      14.0      29.9
#
#        최저기온(°C)  평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# ...

# %%
df = df.drop(df[(df.요일 == 6)].index, axis=0)
df
# Out:
#        Unnamed: 0       date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 25             25 2016-05-02    11680    6421     강남구      21.0      28.5
# 26             26 2016-05-02    11740    5264     강동구      21.0      28.3
# 27             27 2016-05-02    11305    3723     강북구      22.0      28.6
# 28             28 2016-05-02    11500    7800     강서구      15.0      27.8
# 29             29 2016-05-02    11620    5908     관악구      22.5      26.8
# ...           ...        ...      ...     ...     ...       ...       ...
# 19770       19770 2018-06-30    11170     863     용산구      20.0      29.6
# 19771       19771 2018-06-30    11380    2028     은평구      23.5      27.6
# 19772       19772 2018-06-30    11110     508     종로구      14.0      29.9
# 19773       19773 2018-06-30    11140     492      중구       5.0      28.7
# 19774       19774 2018-06-30    11260    1787     중랑구      14.0      29.9
#
#        최저기온(°C)  평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# ...

# %%
df.to_csv("C:\dev_python\project\data_final2\data_good_drop.csv", encoding = 'cp949', index = False)

# %%
df = pd.read_csv('C:\\dev_python\\project\\data_final2\\data_good_drop.csv', encoding = "CP949")
df
# Out:
#        Unnamed: 0      date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 0              25  20160502    11680    6421     강남구      21.0      28.5
# 1              26  20160502    11740    5264     강동구      21.0      28.3
# 2              27  20160502    11305    3723     강북구      22.0      28.6
# 3              28  20160502    11500    7800     강서구      15.0      27.8
# 4              29  20160502    11620    5908     관악구      22.5      26.8
# ...           ...       ...      ...     ...     ...       ...       ...
# 16945       19770  20180630    11170     863     용산구      20.0      29.6
# 16946       19771  20180630    11380    2028     은평구      23.5      27.6
# 16947       19772  20180630    11110     508     종로구      14.0      29.9
# 16948       19773  20180630    11140     492      중구       5.0      28.7
# 16949       19774  20180630    11260    1787     중랑구      14.0      29.9
#
#        최저기온(°C)  평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# ...

# %%
df_drop_hol = df.drop(df[(df.date == 20160101) | \
                          (df.date == 20160208) | (df.date == 20160209) | (df.date == 20160210) | \
                          (df.date == 20160301) | \
                          (df.date == 20160413) | \
                          (df.date == 20160505) | (df.date == 20160506) | (df.date == 20160514) | \
                          (df.date == 20160606) | \
                          (df.date == 20160815) | \
                          (df.date == 20160914) | (df.date == 20160915) | (df.date == 20160916) | \
                          (df.date == 20161003) | \
                          (df.date == 20170127) | (df.date == 20170128) | (df.date == 20170130) | \
                          (df.date == 20170301) | \
                          (df.date == 20170503) | (df.date == 20170505) | (df.date == 20170509) | \
                          (df.date == 20170606) | \
                          (df.date == 20170815) | \
                          (df.date == 20171002) | (df.date == 20171003) | (df.date == 20171004) | (df.date == 20171005) | (df.date == 20171006) | (df.date == 20171009) | \
                          (df.date == 20171220) | (df.date == 20171225) | \
                          (df.date == 20180101) | \
                          (df.date == 20180215) | (df.date == 20180216) | (df.date == 20180217) | \
                          (df.date == 20180301) | \
                          (df.date == 20180505) | (df.date == 20180507) | (df.date == 20180522) | \
                          (df.date == 20180606) | (df.date == 20180613) | \
                          (df.date == 20180815) | \
                          (df.date == 20180924) | (df.date == 20180925) | (df.date == 20180926) | \
                          (df.date == 20181003) | (df.date == 20181009) | \
                          (df.date == 20181225)].index, axis=0)
df_drop_hol
# Out:
#        Unnamed: 0      date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  \
# 0              25  20160502    11680    6421     강남구      21.0      28.5
# 1              26  20160502    11740    5264     강동구      21.0      28.3
# 2              27  20160502    11305    3723     강북구      22.0      28.6
# 3              28  20160502    11500    7800     강서구      15.0      27.8
# 4              29  20160502    11620    5908     관악구      22.5      26.8
# ...           ...       ...      ...     ...     ...       ...       ...
# 16945       19770  20180630    11170     863     용산구      20.0      29.6
# 16946       19771  20180630    11380    2028     은평구      23.5      27.6
# 16947       19772  20180630    11110     508     종로구      14.0      29.9
# 16948       19773  20180630    11140     492      중구       5.0      28.7
# 16949       19774  20180630    11260    1787     중랑구      14.0      29.9
#
#        최저기온(°C)  평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# ...

# %%
df_drop_hol[df_drop_hol.date == 20170127]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, date, gu_code, target, gu_name, 일강수량(mm), 최고기온(°C), 최저기온(°C), 평균 풍속(m/s), 평균기온(°C), 이산화질소농도.ppm., 오존농도.ppm., 이산화탄소농도.ppm., 아황산가스.ppm., 미세먼지....., 초미세먼지....., 검색량, 모기지수, month, 요일]
# Index: []

# %%
df_drop_hol.columns
# Out:
# Index(['Unnamed: 0', 'date', 'gu_code', 'target', 'gu_name', '일강수량(mm)',
#        '최고기온(°C)', '최저기온(°C)', '평균 풍속(m/s)', '평균기온(°C)', '이산화질소농도.ppm.',
#        '오존농도.ppm.', '이산화탄소농도.ppm.', '아황산가스.ppm.', '미세먼지.....', '초미세먼지.....',
#        '검색량', '모기지수', 'month', '요일'],
#       dtype='object')

# %%
df_drop_hol["일교차"] = df_drop_hol["최고기온(°C)"] - df_drop_hol["최저기온(°C)"]

# %%
df_drop_hol
# Out:
#            date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  최저기온(°C)  \
# 0      20160502    11680    6421     강남구      21.0      28.5      17.5
# 1      20160502    11740    5264     강동구      21.0      28.3      15.3
# 2      20160502    11305    3723     강북구      22.0      28.6      17.3
# 3      20160502    11500    7800     강서구      15.0      27.8      17.5
# 4      20160502    11620    5908     관악구      22.5      26.8      15.6
# ...         ...      ...     ...     ...       ...       ...       ...
# 16945  20180630    11170     863     용산구      20.0      29.6      22.5
# 16946  20180630    11380    2028     은평구      23.5      27.6      18.4
# 16947  20180630    11110     508     종로구      14.0      29.9      22.3
# 16948  20180630    11140     492      중구       5.0      28.7      20.9
# 16949  20180630    11260    1787     중랑구      14.0      29.9      22.3
#
#        평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  오존농도.ppm.  이산화탄소농도.ppm.  \
# ...

# %%
df_drop_hol["체감온도"] = 13.12 + 0.6215*df_drop_hol["평균기온(°C)"] - 11.37*df_drop_hol["평균 풍속(m/s)"] \
                        + 0.3965*df_drop_hol["평균 풍속(m/s)"]*df_drop_hol["평균기온(°C)"]
df_drop_hol
# Out:
#            date  gu_code  target gu_name  일강수량(mm)  최고기온(°C)  최저기온(°C)  \
# 0      20160502    11680    6421     강남구      21.0      28.5      17.5
# 1      20160502    11740    5264     강동구      21.0      28.3      15.3
# 2      20160502    11305    3723     강북구      22.0      28.6      17.3
# 3      20160502    11500    7800     강서구      15.0      27.8      17.5
# 4      20160502    11620    5908     관악구      22.5      26.8      15.6
# ...         ...      ...     ...     ...       ...       ...       ...
# 16945  20180630    11170     863     용산구      20.0      29.6      22.5
# 16946  20180630    11380    2028     은평구      23.5      27.6      18.4
# 16947  20180630    11110     508     종로구      14.0      29.9      22.3
# 16948  20180630    11140     492      중구       5.0      28.7      20.9
# 16949  20180630    11260    1787     중랑구      14.0      29.9      22.3
#
#        평균 풍속(m/s)  평균기온(°C)  이산화질소농도.ppm.  ...  이산화탄소농도.ppm.  아황산가스.ppm.  \
# ...

# %%
df_drop_hol.columns
# Out:
# Index(['date', 'gu_code', 'target', 'gu_name', '일강수량(mm)', '최고기온(°C)',
#        '최저기온(°C)', '평균 풍속(m/s)', '평균기온(°C)', '이산화질소농도.ppm.', '오존농도.ppm.',
#        '이산화탄소농도.ppm.', '아황산가스.ppm.', '미세먼지.....', '초미세먼지.....', '검색량', '모기지수',
#        'month', '요일', '일교차', '체감온도'],
#       dtype='object')

# %%
df_drop_hol.columns = (['date', 'gu_code', 'target', 'gu_name', '강수량(mm)', '최고기온(°C)',
       '최저기온(°C)', '평균풍속(m/s)', '평균기온(°C)', '이산화질소농도.ppm.', '오존농도.ppm.',
       '이산화탄소농도.ppm.', '아황산가스.ppm.', '미세먼지', '초미세먼지', '검색량', '모기지수',
       'month', '요일', '일교차', '체감온도'])

# %%
df_drop_hol.columns
# Out:
# Index(['date', 'gu_code', 'target', 'gu_name', '강수량(mm)', '최고기온(°C)',
#        '최저기온(°C)', '평균풍속(m/s)', '평균기온(°C)', '이산화질소농도.ppm.', '오존농도.ppm.',
#        '이산화탄소농도.ppm.', '아황산가스.ppm.', '미세먼지', '초미세먼지', '검색량', '모기지수', 'month',
#        '요일', '일교차', '체감온도'],
#       dtype='object')

# %%
df_drop_hol_col = df_drop_hol[['target', 'date', 'month', '요일', 'gu_code', 'gu_name', '최고기온(°C)', '평균기온(°C)',
       '최저기온(°C)', '일교차', '체감온도', '강수량(mm)', '평균풍속(m/s)', '미세먼지', '초미세먼지', '검색량', '모기지수']]

# %%
df_drop_hol_col
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16945     863  20180630      6   5    11170     용산구      29.6      24.8
# 16946    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16947     508  20180630      6   5    11110     종로구      29.9      25.3
# 16948     492  20180630      6   5    11140      중구      28.7      23.5
# 16949    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
df_drop_hol_col.to_csv("C:\dev_python\project\data_final2\data_678_drop_final.csv", encoding = 'cp949', index = False)

# %%
df = pd.read_csv("C:\dev_python\project\data_final2\data_678_drop_final.csv", encoding = "CP949")
df.head()
# Out:
#    target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  최저기온(°C)  \
# 0    6421  20160502      5   0    11680     강남구      28.5      21.3      17.5
# 1    5264  20160502      5   0    11740     강동구      28.3      20.7      15.3
# 2    3723  20160502      5   0    11305     강북구      28.6      21.4      17.3
# 3    7800  20160502      5   0    11500     강서구      27.8      21.1      17.5
# 4    5908  20160502      5   0    11620     관악구      26.8      19.8      15.6
#
#     일교차      체감온도  강수량(mm)  평균풍속(m/s)  미세먼지  초미세먼지      검색량   모기지수
# 0  11.0  22.26358     21.0        1.4  44.0   26.0  4.79001  273.5
# 1  13.0  20.92513     21.0        1.6  50.0   26.0  4.79001  273.5
# 2  11.3  21.51577     22.0        1.7  38.0   21.0  4.79001  273.5
# 3  10.3  18.42364     15.0        2.6  49.0   23.0  4.79001  273.5
# 4  11.2  17.33131     22.5        2.3  44.0   25.0  4.79001  273.5

# %%
df2 = pd.read_csv("C:\dev_python\project\data_final\\cold_final.csv", encoding = "CP949")
df2.head()
# Out:
#          날짜  시군구지역코드  발생건수(건) 시군구명
# 0  20140101    11110       53  종로구
# 1  20140102    11110     1408  종로구
# 2  20140103    11110     1129  종로구
# 3  20140104    11110      890  종로구
# 4  20140105    11110      134  종로구

# %%
df2 = df2[df2.날짜 >= 20160501]
df2
# Out:
#              날짜  시군구지역코드  발생건수(건) 시군구명
# 851    20160501    11110      132  종로구
# 852    20160502    11110     1535  종로구
# 853    20160503    11110      878  종로구
# 854    20160504    11110     1232  종로구
# 855    20160505    11110      136  종로구
# ...         ...      ...      ...  ...
# 41045  20180626    11740     1796  강동구
# 41046  20180627    11740     2135  강동구
# 41047  20180628    11740     2025  강동구
# 41048  20180629    11740     2360  강동구
# 41049  20180630    11740     1985  강동구
#
# [19775 rows x 4 columns]

# %%
df2.columns = ["date2", "시군구지역코드", "target2", "시군구명"]
df2.columns
# Out:
# Index(['date2', '시군구지역코드', 'target2', '시군구명'], dtype='object')

# %%
df2["date2"].dtype
# Out:
# dtype('int64')

# %%
df2["date2"] = df2["date2"].astype(str)

df2["date2"] = df2["date2"].str[0:4] + "-" + df2["date2"].str[4:6] + "-" + df2["date2"].str[6:8]

df2["date2"] = df2["date2"].astype('datetime64[ns]')

# %%
df2
# Out:
#            date2  시군구지역코드  target2 시군구명
# 851   2016-05-01    11110      132  종로구
# 852   2016-05-02    11110     1535  종로구
# 853   2016-05-03    11110      878  종로구
# 854   2016-05-04    11110     1232  종로구
# 855   2016-05-05    11110      136  종로구
# ...          ...      ...      ...  ...
# 41045 2018-06-26    11740     1796  강동구
# 41046 2018-06-27    11740     2135  강동구
# 41047 2018-06-28    11740     2025  강동구
# 41048 2018-06-29    11740     2360  강동구
# 41049 2018-06-30    11740     1985  강동구
#
# [19775 rows x 4 columns]

# %%
df2["date2"] = df2["date2"] - pd.DateOffset(days=5)
#df2 = df2.drop('date2', axis =1)
df2
# Out:
#            date2  시군구지역코드  target2 시군구명
# 851   2016-04-26    11110      132  종로구
# 852   2016-04-27    11110     1535  종로구
# 853   2016-04-28    11110      878  종로구
# 854   2016-04-29    11110     1232  종로구
# 855   2016-04-30    11110      136  종로구
# ...          ...      ...      ...  ...
# 41045 2018-06-21    11740     1796  강동구
# 41046 2018-06-22    11740     2135  강동구
# 41047 2018-06-23    11740     2025  강동구
# 41048 2018-06-24    11740     2360  강동구
# 41049 2018-06-25    11740     1985  강동구
#
# [19775 rows x 4 columns]

# %%
df2["date2"] = df2["date2"].astype('str')

df2["date2"] = df2["date2"].str[0:4] + df2["date2"].str[5:7] + df2["date2"].str[8:10]

df2["date2"] = df2["date2"].astype('int')

df2
# Out:
#           date2  시군구지역코드  target2 시군구명
# 851    20160426    11110      132  종로구
# 852    20160427    11110     1535  종로구
# 853    20160428    11110      878  종로구
# 854    20160429    11110     1232  종로구
# 855    20160430    11110      136  종로구
# ...         ...      ...      ...  ...
# 41045  20180621    11740     1796  강동구
# 41046  20180622    11740     2135  강동구
# 41047  20180623    11740     2025  강동구
# 41048  20180624    11740     2360  강동구
# 41049  20180625    11740     1985  강동구
#
# [19775 rows x 4 columns]

# %%
df3 = df.merge(df2, left_on=['date', 'gu_code'], right_on=['date2', '시군구지역코드'], how = 'inner') 
df3 = df3.drop(['date', '시군구지역코드', 'target', '시군구명'], axis=1)
df3
# Out:
#        month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  최저기온(°C)   일교차  \
# 0          5   0    11680     강남구      28.5      21.3      17.5  11.0
# 1          5   0    11740     강동구      28.3      20.7      15.3  13.0
# 2          5   0    11305     강북구      28.6      21.4      17.3  11.3
# 3          5   0    11500     강서구      27.8      21.1      17.5  10.3
# 4          5   0    11620     관악구      26.8      19.8      15.6  11.2
# ...      ...  ..      ...     ...       ...       ...       ...   ...
# 15920      6   0    11170     용산구      33.9      27.6      22.0  11.9
# 15921      6   0    11380     은평구      31.9      24.3      17.5  14.4
# 15922      6   0    11110     종로구      33.6      28.0      22.2  11.4
# 15923      6   0    11140      중구      33.1      26.1      20.1  13.0
# 15924      6   0    11260     중랑구      33.6      28.0      22.2  11.4
#
#            체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지      검색량   모기지수  \
# ...

# %%
df3.to_csv("C:\dev_python\project\data_final2\data_678_5day.csv", encoding = 'cp949', index = False)

# %% [markdown]
# # ============================================================

# %% [markdown]
# # Drop (sun, hol) : 3 class

# %%
cd = pd.read_csv("data_678_drop_final.csv", encoding = "CP949")
cd.head()
# Out:
#    target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  최저기온(°C)  \
# 0    6421  20160502      5   0    11680     강남구      28.5      21.3      17.5
# 1    5264  20160502      5   0    11740     강동구      28.3      20.7      15.3
# 2    3723  20160502      5   0    11305     강북구      28.6      21.4      17.3
# 3    7800  20160502      5   0    11500     강서구      27.8      21.1      17.5
# 4    5908  20160502      5   0    11620     관악구      26.8      19.8      15.6
#
#     일교차      체감온도  강수량(mm)  평균풍속(m/s)  미세먼지  초미세먼지      검색량   모기지수
# 0  11.0  22.26358     21.0        1.4  44.0   26.0  4.79001  273.5
# 1  13.0  20.92513     21.0        1.6  50.0   26.0  4.79001  273.5
# 2  11.3  21.51577     22.0        1.7  38.0   21.0  4.79001  273.5
# 3  10.3  18.42364     15.0        2.6  49.0   23.0  4.79001  273.5
# 4  11.2  17.33131     22.5        2.3  44.0   25.0  4.79001  273.5

# %%
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
16050 / 3
# Out:
# 5350.0

# %%
cd2 = cd.sort_values(by = "target")
cd2
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 2147      362  20160813      8   5    11110     종로구      36.0      31.1
# 1998      378  20160806      8   5    11140      중구      34.1      29.5
# 2148      387  20160813      8   5    11140      중구      35.5      29.2
# 9473      400  20170805      8   5    11140      중구      35.6      30.1
# 9623      406  20170812      8   5    11140      중구      31.5      26.2
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 12278   12212  20171226     12   1    11500     강서구      -0.2      -3.8
# 4728    12342  20161219     12   0    11500     강서구      11.8       8.3
# 12417   12352  20180102      1   1    11710     송파구       2.4      -0.6
# 12292   12482  20171226     12   1    11710     송파구       0.9      -2.6
# 4742    12762  20161219     12   0    11710     송파구      12.2       8.2
#
#        최저기온(°C)  일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd_low = cd2.iloc[:5350,:]
cd_low
# Out:
#       target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 2147     362  20160813      8   5    11110     종로구      36.0      31.1
# 1998     378  20160806      8   5    11140      중구      34.1      29.5
# 2148     387  20160813      8   5    11140      중구      35.5      29.2
# 9473     400  20170805      8   5    11140      중구      35.6      30.1
# 9623     406  20170812      8   5    11140      중구      31.5      26.2
# ...      ...       ...    ...  ..      ...     ...       ...       ...
# 8406    2273  20170617      6   5    11530     구로구      28.8      23.3
# 2461    2273  20160830      8   1    11590     동작구      25.4      21.3
# 8481    2273  20170621      6   2    11530     구로구      31.0      24.6
# 8451    2274  20170620      6   1    11740     강동구      31.8      25.6
# 7952    2274  20170526      5   4    11305     강북구      23.0      17.9
#
#       최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)  미세먼지  초미세먼지      검색량  \
# ...

# %%
cd_middle = cd2.iloc[5350:10700,:]
cd_middle
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 1293     2274  20160705      7   1    11470     양천구      26.0      23.8
# 8055     2275  20170531      5   2    11215     광진구      30.0      23.4
# 9733     2275  20170819      8   5    11350     노원구      27.6      24.4
# 14865    2275  20180501      5   1    11200     성동구      24.2      21.1
# 10607    2275  20170929      9   4    11545     금천구      21.2      17.3
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 3951     3370  20161112     11   5    11740     강동구      17.0      11.7
# 600      3371  20160602      6   3    11680     강남구      29.1      24.1
# 10175    3371  20170909      9   5    11680     강남구      28.9      24.6
# 10904    3371  20171020     10   4    11620     관악구      22.0      13.9
# 14204    3371  20180331      3   5    11620     관악구      19.4      11.9
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지  초미세먼지  \
# ...

# %%
cd_high = cd2.iloc[10700:,:]
cd_high
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 13135    3372  20180205      2   0    11230    동대문구      -4.5      -8.0
# 3471     3373  20161020     10   3    11380     은평구      24.9      16.8
# 11649    3373  20171123     11   3    11260     중랑구       5.1       1.9
# 3816     3374  20161105     11   5    11290     성북구      18.2      15.0
# 5111     3374  20170105      1   3    11590     동작구       8.5       4.1
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 12278   12212  20171226     12   1    11500     강서구      -0.2      -3.8
# 4728    12342  20161219     12   0    11500     강서구      11.8       8.3
# 12417   12352  20180102      1   1    11710     송파구       2.4      -0.6
# 12292   12482  20171226     12   1    11710     송파구       0.9      -2.6
# 4742    12762  20161219     12   0    11710     송파구      12.2       8.2
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd["class"] = [ i for i in cd["target"] 0 if i <= 2274 ]

# %%
cd["class"] = cd.apply(lambda x:
         0 if (x['target'] <= 2274)
         else 1
         if (x['target'] <= 3371)
         else 2, axis = 1)

# %%
cd["class"].value_counts()
# Out:
# 0    5351
# 2    5350
# 1    5349
# Name: class, dtype: int64

# %%
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd.to_csv("C:\dev_python\project\data_final2\data_drop_3class.csv", encoding = 'cp949', index = False)

# %% [markdown]
# # Drop (sun, hol) : 2 class

# %%
cd = pd.read_csv("data_678_drop_final.csv", encoding = "CP949")
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
16050 / 2
# Out:
# 8025.0

# %%
cd2 = cd.sort_values(by = "target")
cd2
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 2147      362  20160813      8   5    11110     종로구      36.0      31.1
# 1998      378  20160806      8   5    11140      중구      34.1      29.5
# 2148      387  20160813      8   5    11140      중구      35.5      29.2
# 9473      400  20170805      8   5    11140      중구      35.6      30.1
# 9623      406  20170812      8   5    11140      중구      31.5      26.2
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 12278   12212  20171226     12   1    11500     강서구      -0.2      -3.8
# 4728    12342  20161219     12   0    11500     강서구      11.8       8.3
# 12417   12352  20180102      1   1    11710     송파구       2.4      -0.6
# 12292   12482  20171226     12   1    11710     송파구       0.9      -2.6
# 4742    12762  20161219     12   0    11710     송파구      12.2       8.2
#
#        최저기온(°C)  일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd_low = cd2.iloc[:8025,:]
cd_low
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 2147      362  20160813      8   5    11110     종로구      36.0      31.1
# 1998      378  20160806      8   5    11140      중구      34.1      29.5
# 2148      387  20160813      8   5    11140      중구      35.5      29.2
# 9473      400  20170805      8   5    11140      중구      35.6      30.1
# 9623      406  20170812      8   5    11140      중구      31.5      26.2
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 366      2788  20160521      5   5    11290     성북구      29.2      23.5
# 2699     2788  20160909      9   4    11260     중랑구      29.0      24.1
# 11537    2788  20171118     11   5    11440     마포구       2.4      -2.2
# 10139    2788  20170907      9   3    11650     서초구      27.6      22.4
# 9567     2789  20170810      8   3    11710     송파구      26.4      24.8
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)  미세먼지  초미세먼지      검색량  \
# ...

# %%
cd_middle = cd2.iloc[8025:]
cd_middle
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 13191    2789  20180207      2   2    11290     성북구      -2.8      -7.8
# 8241     2789  20170609      6   4    11290     성북구      25.6      20.8
# 666      2789  20160604      6   5    11290     성북구      25.4      21.0
# 11284    2790  20171107     11   1    11320     도봉구      17.3      12.8
# 10121    2790  20170906      9   2    11380     은평구      23.6      18.9
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 12278   12212  20171226     12   1    11500     강서구      -0.2      -3.8
# 4728    12342  20161219     12   0    11500     강서구      11.8       8.3
# 12417   12352  20180102      1   1    11710     송파구       2.4      -0.6
# 12292   12482  20171226     12   1    11710     송파구       0.9      -2.6
# 4742    12762  20161219     12   0    11710     송파구      12.2       8.2
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd["class"] = cd.apply(lambda x:
         0 if (x['target'] <= 2788)
         else 1, axis = 1)

# %%
cd["class"].value_counts()
# Out:
# 1    8026
# 0    8024
# Name: class, dtype: int64

# %%
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd.to_csv("data_drop_2class.csv", encoding = 'cp949', index = False)

# %% [markdown]
# # Drop (sun, hol) : 3 class

# %%
cd = pd.read_csv("data_678_drop_final.csv", encoding = "CP949")
cd.head()
# Out:
#    target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  최저기온(°C)  \
# 0    6421  20160502      5   0    11680     강남구      28.5      21.3      17.5
# 1    5264  20160502      5   0    11740     강동구      28.3      20.7      15.3
# 2    3723  20160502      5   0    11305     강북구      28.6      21.4      17.3
# 3    7800  20160502      5   0    11500     강서구      27.8      21.1      17.5
# 4    5908  20160502      5   0    11620     관악구      26.8      19.8      15.6
#
#     일교차      체감온도  강수량(mm)  평균풍속(m/s)  미세먼지  초미세먼지      검색량   모기지수
# 0  11.0  22.26358     21.0        1.4  44.0   26.0  4.79001  273.5
# 1  13.0  20.92513     21.0        1.6  50.0   26.0  4.79001  273.5
# 2  11.3  21.51577     22.0        1.7  38.0   21.0  4.79001  273.5
# 3  10.3  18.42364     15.0        2.6  49.0   23.0  4.79001  273.5
# 4  11.2  17.33131     22.5        2.3  44.0   25.0  4.79001  273.5

# %%
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
16050 / 3
# Out:
# 5350.0

# %%
cd2 = cd.sort_values(by = "target")
cd2
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 2147      362  20160813      8   5    11110     종로구      36.0      31.1
# 1998      378  20160806      8   5    11140      중구      34.1      29.5
# 2148      387  20160813      8   5    11140      중구      35.5      29.2
# 9473      400  20170805      8   5    11140      중구      35.6      30.1
# 9623      406  20170812      8   5    11140      중구      31.5      26.2
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 12278   12212  20171226     12   1    11500     강서구      -0.2      -3.8
# 4728    12342  20161219     12   0    11500     강서구      11.8       8.3
# 12417   12352  20180102      1   1    11710     송파구       2.4      -0.6
# 12292   12482  20171226     12   1    11710     송파구       0.9      -2.6
# 4742    12762  20161219     12   0    11710     송파구      12.2       8.2
#
#        최저기온(°C)  일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd_low = cd2.iloc[:5350,:]
cd_low
# Out:
#       target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 2147     362  20160813      8   5    11110     종로구      36.0      31.1
# 1998     378  20160806      8   5    11140      중구      34.1      29.5
# 2148     387  20160813      8   5    11140      중구      35.5      29.2
# 9473     400  20170805      8   5    11140      중구      35.6      30.1
# 9623     406  20170812      8   5    11140      중구      31.5      26.2
# ...      ...       ...    ...  ..      ...     ...       ...       ...
# 8406    2273  20170617      6   5    11530     구로구      28.8      23.3
# 2461    2273  20160830      8   1    11590     동작구      25.4      21.3
# 8481    2273  20170621      6   2    11530     구로구      31.0      24.6
# 8451    2274  20170620      6   1    11740     강동구      31.8      25.6
# 7952    2274  20170526      5   4    11305     강북구      23.0      17.9
#
#       최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)  미세먼지  초미세먼지      검색량  \
# ...

# %%
cd_middle = cd2.iloc[5350:10700,:]
cd_middle
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 1293     2274  20160705      7   1    11470     양천구      26.0      23.8
# 8055     2275  20170531      5   2    11215     광진구      30.0      23.4
# 9733     2275  20170819      8   5    11350     노원구      27.6      24.4
# 14865    2275  20180501      5   1    11200     성동구      24.2      21.1
# 10607    2275  20170929      9   4    11545     금천구      21.2      17.3
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 3951     3370  20161112     11   5    11740     강동구      17.0      11.7
# 600      3371  20160602      6   3    11680     강남구      29.1      24.1
# 10175    3371  20170909      9   5    11680     강남구      28.9      24.6
# 10904    3371  20171020     10   4    11620     관악구      22.0      13.9
# 14204    3371  20180331      3   5    11620     관악구      19.4      11.9
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지  초미세먼지  \
# ...

# %%
cd_high = cd2.iloc[10700:,:]
cd_high
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 13135    3372  20180205      2   0    11230    동대문구      -4.5      -8.0
# 3471     3373  20161020     10   3    11380     은평구      24.9      16.8
# 11649    3373  20171123     11   3    11260     중랑구       5.1       1.9
# 3816     3374  20161105     11   5    11290     성북구      18.2      15.0
# 5111     3374  20170105      1   3    11590     동작구       8.5       4.1
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 12278   12212  20171226     12   1    11500     강서구      -0.2      -3.8
# 4728    12342  20161219     12   0    11500     강서구      11.8       8.3
# 12417   12352  20180102      1   1    11710     송파구       2.4      -0.6
# 12292   12482  20171226     12   1    11710     송파구       0.9      -2.6
# 4742    12762  20161219     12   0    11710     송파구      12.2       8.2
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd["class"] = [ i for i in cd["target"] 0 if i <= 2274 ]

# %%
cd["class"] = cd.apply(lambda x:
         0 if (x['target'] <= 2274)
         else 1
         if (x['target'] <= 3371)
         else 2, axis = 1)

# %%
cd["class"].value_counts()
# Out:
# 0    5351
# 2    5350
# 1    5349
# Name: class, dtype: int64

# %%
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd.to_csv("C:\dev_python\project\data_final2\data_drop_3class.csv", encoding = 'cp949', index = False)

# %% [markdown]
# # Drop (sun, hol) : 2 class

# %%
cd = pd.read_csv("data_678_drop_final.csv", encoding = "CP949")
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
16050 / 2
# Out:
# 8025.0

# %%
cd2 = cd.sort_values(by = "target")
cd2
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 2147      362  20160813      8   5    11110     종로구      36.0      31.1
# 1998      378  20160806      8   5    11140      중구      34.1      29.5
# 2148      387  20160813      8   5    11140      중구      35.5      29.2
# 9473      400  20170805      8   5    11140      중구      35.6      30.1
# 9623      406  20170812      8   5    11140      중구      31.5      26.2
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 12278   12212  20171226     12   1    11500     강서구      -0.2      -3.8
# 4728    12342  20161219     12   0    11500     강서구      11.8       8.3
# 12417   12352  20180102      1   1    11710     송파구       2.4      -0.6
# 12292   12482  20171226     12   1    11710     송파구       0.9      -2.6
# 4742    12762  20161219     12   0    11710     송파구      12.2       8.2
#
#        최저기온(°C)  일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd_low = cd2.iloc[:8025,:]
cd_low
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 2147      362  20160813      8   5    11110     종로구      36.0      31.1
# 1998      378  20160806      8   5    11140      중구      34.1      29.5
# 2148      387  20160813      8   5    11140      중구      35.5      29.2
# 9473      400  20170805      8   5    11140      중구      35.6      30.1
# 9623      406  20170812      8   5    11140      중구      31.5      26.2
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 366      2788  20160521      5   5    11290     성북구      29.2      23.5
# 2699     2788  20160909      9   4    11260     중랑구      29.0      24.1
# 11537    2788  20171118     11   5    11440     마포구       2.4      -2.2
# 10139    2788  20170907      9   3    11650     서초구      27.6      22.4
# 9567     2789  20170810      8   3    11710     송파구      26.4      24.8
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)  미세먼지  초미세먼지      검색량  \
# ...

# %%
cd_middle = cd2.iloc[8025:]
cd_middle
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 13191    2789  20180207      2   2    11290     성북구      -2.8      -7.8
# 8241     2789  20170609      6   4    11290     성북구      25.6      20.8
# 666      2789  20160604      6   5    11290     성북구      25.4      21.0
# 11284    2790  20171107     11   1    11320     도봉구      17.3      12.8
# 10121    2790  20170906      9   2    11380     은평구      23.6      18.9
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 12278   12212  20171226     12   1    11500     강서구      -0.2      -3.8
# 4728    12342  20161219     12   0    11500     강서구      11.8       8.3
# 12417   12352  20180102      1   1    11710     송파구       2.4      -0.6
# 12292   12482  20171226     12   1    11710     송파구       0.9      -2.6
# 4742    12762  20161219     12   0    11710     송파구      12.2       8.2
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd["class"] = cd.apply(lambda x:
         0 if (x['target'] <= 2788)
         else 1, axis = 1)

# %%
cd["class"].value_counts()
# Out:
# 1    8026
# 0    8024
# Name: class, dtype: int64

# %%
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd.to_csv("data_drop_2class.csv", encoding = 'cp949', index = False)

# %% [markdown]
# # Real : 3 class

# %%
cd = pd.read_csv("REAL_DATA.csv", encoding = "CP949")
cd.head()
# Out:
#        date  month  gu_code  target gu_name  일교차  기온(°C)      체감온도  강수량(mm)  \
# 0  20170101      1    11110      68     종로구  5.8     2.5  1.181375      0.0
# 1  20170101      1    11110      68     종로구  5.8     2.5  1.181375      0.0
# 2  20170101      1    11110      68     종로구  5.8     2.5  1.181375      0.0
# 3  20170101      1    11110      68     종로구  5.8     2.5  1.181375      0.0
# 4  20170101      1    11110      68     종로구  5.8     2.5  1.181375      0.0
#
#    풍속(m/s)  ...   총생활인구수_LF    총생활인구수_TF  노선명   역ID    역명   총승객수 승차총승객수  \
# 0      1.3  ...  18442.7231  21814.17021  1호선   152    종각  37022  21002
# 1      1.3  ...  18442.7231  21814.17021  1호선   153  종로3가  33087  18000
# 2      1.3  ...  18442.7231  21814.17021  3호선   319  종로3가   7202   2749
# 3      1.3  ...  18442.7231  21814.17021  5호선  2535  종로3가  14097   7415
# 4      1.3  ...  18442.7231  21814.17021  1호선   154  종로5가  18626   9448
#
#    하차총승객수 모기지수      검색량
# 0   16020  1.0  5.80072
# 1   15087  1.0  5.80072
# ...

# %%
cd
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 0       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 1       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 2       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 3       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 4       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# ...          ...    ...      ...     ...     ...  ...     ...        ...
# 157639  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157640  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157641  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157642  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157643  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
#
#         강수량(mm)  풍속(m/s)  ...   총생활인구수_LF     총생활인구수_TF  노선명   역ID    역명  \
# ...

# %%
cd2 = cd.sort_values(by = "target")
cd2
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)      체감온도  \
# 117920  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# 117928  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# 117927  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# 117926  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# 117925  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# ...          ...    ...      ...     ...     ...  ...     ...       ...
# 102915  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102914  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102919  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102908  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102920  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
#
#         강수량(mm)  풍속(m/s)  ...    총생활인구수_LF     총생활인구수_TF     노선명   역ID     역명  \
# ...

# %%
157644  / 3
# Out:
# 52548.0

# %%
cd_low = cd2.iloc[:52548,:]
cd_low
# Out:
#             date  month  gu_code  target gu_name   일교차  기온(°C)      체감온도  \
# 117920  20180216      2    11110      32     종로구   7.6    -2.6 -14.53779
# 117928  20180216      2    11110      32     종로구   7.6    -2.6 -14.53779
# 117927  20180216      2    11110      32     종로구   7.6    -2.6 -14.53779
# 117926  20180216      2    11110      32     종로구   7.6    -2.6 -14.53779
# 117925  20180216      2    11110      32     종로구   7.6    -2.6 -14.53779
# ...          ...    ...      ...     ...     ...   ...     ...       ...
# 23463   20170325      3    11170    1746     용산구   6.2     8.8   2.82760
# 23462   20170325      3    11170    1746     용산구   6.2     8.8   2.82760
# 55252   20170715      7    11560    1746    영등포구   4.7    25.2  27.12796
# 156065  20180625      6    11545    1746     금천구  10.7    27.3  29.32318
# 156066  20180625      6    11545    1746     금천구  10.7    27.3  29.32318
#
#         강수량(mm)  풍속(m/s)  ...    총생활인구수_LF     총생활인구수_TF  노선명   역ID       역명  \
# ...

# %%
cd_middle = cd2.iloc[52548:-52548,:]
cd_middle
# Out:
#             date  month  gu_code  target gu_name   일교차  기온(°C)      체감온도  \
# 156067  20180625      6    11545    1746     금천구  10.7    27.3  29.32318
# 156068  20180625      6    11545    1746     금천구  10.7    27.3  29.32318
# 55251   20170715      7    11560    1746    영등포구   4.7    25.2  27.12796
# 55250   20170715      7    11560    1746    영등포구   4.7    25.2  27.12796
# 55249   20170715      7    11560    1746    영등포구   4.7    25.2  27.12796
# ...          ...    ...      ...     ...     ...   ...     ...       ...
# 25587   20170401      4    11560    3303    영등포구   9.1     9.8  10.22954
# 25588   20170401      4    11560    3303    영등포구   9.1     9.8  10.22954
# 25590   20170401      4    11560    3303    영등포구   9.1     9.8  10.22954
# 68564   20170831      8    11680    3303     강남구  10.6    22.8  24.49444
# 25592   20170401      4    11560    3303    영등포구   9.1     9.8  10.22954
#
#         강수량(mm)  풍속(m/s)  ...    총생활인구수_LF     총생활인구수_TF  노선명   역ID     역명  \
# ...

# %%
cd_high = cd2.iloc[-52548:,:]
cd_high
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)      체감온도  \
# 25593   20170401      4    11560    3303    영등포구  9.1     9.8  10.22954
# 25594   20170401      4    11560    3303    영등포구  9.1     9.8  10.22954
# 25595   20170401      4    11560    3303    영등포구  9.1     9.8  10.22954
# 25596   20170401      4    11560    3303    영등포구  9.1     9.8  10.22954
# 25597   20170401      4    11560    3303    영등포구  9.1     9.8  10.22954
# ...          ...    ...      ...     ...     ...  ...     ...       ...
# 102915  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102914  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102919  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102908  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102920  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
#
#         강수량(mm)  풍속(m/s)  ...    총생활인구수_LF    총생활인구수_TF     노선명   역ID     역명  \
# ...

# %%
cd["class"] = cd.apply(lambda x:
         0 if (x['target'] < 1746)
         else 1
         if (x['target'] < 3303)
         else 2, axis = 1)

# %%
cd["class"].value_counts()
# Out:
# 2    52574
# 1    52542
# 0    52528
# Name: class, dtype: int64

# %%
cd
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 0       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 1       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 2       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 3       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 4       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# ...          ...    ...      ...     ...     ...  ...     ...        ...
# 157639  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157640  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157641  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157642  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157643  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
#
#         강수량(mm)  풍속(m/s)  ...     총생활인구수_TF  노선명   역ID    역명   총승객수  승차총승객수  \
# ...

# %%
cd.to_csv("data_real_3class.csv", encoding = 'cp949', index = False)

# %% [markdown]
# # Real : 2 class

# %%
cd = pd.read_csv("REAL_DATA.csv", encoding = "CP949")
cd
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 0       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 1       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 2       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 3       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# 4       20170101      1    11110      68     종로구  5.8     2.5   1.181375
# ...          ...    ...      ...     ...     ...  ...     ...        ...
# 157639  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157640  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157641  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157642  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 157643  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
#
#         강수량(mm)  풍속(m/s)  ...   총생활인구수_LF     총생활인구수_TF  노선명   역ID    역명  \
# ...

# %%
157644  / 2
# Out:
# 78822.0

# %%
cd2 = cd.sort_values(by = "target")
cd2
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)      체감온도  \
# 117920  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# 117928  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# 117927  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# 117926  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# 117925  20180216      2    11110      32     종로구  7.6    -2.6 -14.53779
# ...          ...    ...      ...     ...     ...  ...     ...       ...
# 102915  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102914  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102919  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102908  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
# 102920  20171226     12    11710   12482     송파구  7.6    -2.6 -23.21842
#
#         강수량(mm)  풍속(m/s)  ...    총생활인구수_LF     총생활인구수_TF     노선명   역ID     역명  \
# ...

# %%
cd_low = cd2.iloc[:78822,:]
cd_low
# Out:
#             date  month  gu_code  target gu_name   일교차  기온(°C)       체감온도  \
# 117920  20180216      2    11110      32     종로구   7.6    -2.6 -14.537790
# 117928  20180216      2    11110      32     종로구   7.6    -2.6 -14.537790
# 117927  20180216      2    11110      32     종로구   7.6    -2.6 -14.537790
# 117926  20180216      2    11110      32     종로구   7.6    -2.6 -14.537790
# 117925  20180216      2    11110      32     종로구   7.6    -2.6 -14.537790
# ...          ...    ...      ...     ...     ...   ...     ...        ...
# 35491   20170506      5    11590    2596     동작구  11.8    14.7   8.402425
# 13624   20170218      2    11260    2596     중랑구   8.4    -0.8 -15.426480
# 13623   20170218      2    11260    2596     중랑구   8.4    -0.8 -15.426480
# 13618   20170218      2    11260    2596     중랑구   8.4    -0.8 -15.426480
# 153910  20180618      6    11320    2596     도봉구  12.6    23.8  25.978400
#
#         강수량(mm)  풍속(m/s)  ...     총생활인구수_LF     총생활인구수_TF  노선명   역ID    역명  \
# ...

# %%
cd_middle = cd2.iloc[78822:]
cd_middle
# Out:
#             date  month  gu_code  target gu_name   일교차  기온(°C)       체감온도  \
# 35485   20170506      5    11590    2596     동작구  11.8    14.7   8.402425
# 12779   20170215      2    11290    2596     성북구  10.4     2.1   5.995270
# 13619   20170218      2    11260    2596     중랑구   8.4    -0.8 -15.426480
# 13620   20170218      2    11260    2596     중랑구   8.4    -0.8 -15.426480
# 13621   20170218      2    11260    2596     중랑구   8.4    -0.8 -15.426480
# ...          ...    ...      ...     ...     ...   ...     ...        ...
# 102915  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 102914  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 102919  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 102908  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 102920  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
#
#         강수량(mm)  풍속(m/s)  ...     총생활인구수_LF    총생활인구수_TF     노선명   역ID     역명  \
# ...

# %%
cd["class"] = cd.apply(lambda x:
         0 if (x['target'] <= 2596)
         else 1, axis = 1)

# %%
cd["class"].value_counts()
# Out:
# 0    78846
# 1    78798
# Name: class, dtype: int64

# %%
cd
# Out:
#        target      date  month  요일  gu_code gu_name  최고기온(°C)  평균기온(°C)  \
# 0        6421  20160502      5   0    11680     강남구      28.5      21.3
# 1        5264  20160502      5   0    11740     강동구      28.3      20.7
# 2        3723  20160502      5   0    11305     강북구      28.6      21.4
# 3        7800  20160502      5   0    11500     강서구      27.8      21.1
# 4        5908  20160502      5   0    11620     관악구      26.8      19.8
# ...       ...       ...    ...  ..      ...     ...       ...       ...
# 16045     863  20180630      6   5    11170     용산구      29.6      24.8
# 16046    2028  20180630      6   5    11380     은평구      27.6      22.7
# 16047     508  20180630      6   5    11110     종로구      29.9      25.3
# 16048     492  20180630      6   5    11140      중구      28.7      23.5
# 16049    1787  20180630      6   5    11260     중랑구      29.9      25.3
#
#        최저기온(°C)   일교차       체감온도  강수량(mm)  평균풍속(m/s)       미세먼지      초미세먼지  \
# ...

# %%
cd.to_csv("data_real_2class.csv", encoding = 'cp949', index = False)

# %% [markdown]
# # Real (sun, hol) : 3 class

# %%
cd = pd.read_csv("REAL_DATA_DROP_sun_hol.csv", encoding = "CP949")
cd.head()
# Out:
#        date  month  gu_code  target gu_name  일교차  기온(°C)    체감온도  강수량(mm)  \
# 0  20170102      1    11110    1912     종로구  6.2     4.0 -1.0268      0.0
# 1  20170102      1    11110    1912     종로구  6.2     4.0 -1.0268      0.0
# 2  20170102      1    11110    1912     종로구  6.2     4.0 -1.0268      0.0
# 3  20170102      1    11110    1912     종로구  6.2     4.0 -1.0268      0.0
# 4  20170102      1    11110    1912     종로구  6.2     4.0 -1.0268      0.0
#
#    풍속(m/s)  ...    역명    총승객수  승차총승객수  하차총승객수  모기지수      검색량     y  m  d  요일
# 0      1.7  ...    종각  100401   51435   48966   1.1  7.78878  2017  1  2   0
# 1      1.7  ...  종로3가   22692    9942   12750   1.1  7.78878  2017  1  2   0
# 2      1.7  ...  종로3가   74417   38396   36021   1.1  7.78878  2017  1  2   0
# 3      1.7  ...  종로3가   29135   14540   14595   1.1  7.78878  2017  1  2   0
# 4      1.7  ...  종로5가   52221   26030   26191   1.1  7.78878  2017  1  2   0
#
# [5 rows x 28 columns]

# %%
cd
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 0       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 1       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 2       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 3       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 4       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# ...          ...    ...      ...     ...     ...  ...     ...        ...
# 127296  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127297  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127298  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127299  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127300  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
#
#         강수량(mm)  풍속(m/s)  ...    역명    총승객수  승차총승객수  하차총승객수   모기지수      검색량  \
# ...

# %%
127301  / 3
# Out:
# 42433.666666666664

# %%
cd2 = cd.sort_values(by = "target")
cd2
# Out:
#            date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 49997  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 50001  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 50000  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 49999  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 49998  20170805      8    11140     400      중구  9.1    30.1  33.125845
# ...         ...    ...      ...     ...     ...  ...     ...        ...
# 83153  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
# 83152  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
# 83168  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
# 83158  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
# 83167  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
#
#        강수량(mm)  풍속(m/s)  ...     역명   총승객수  승차총승객수  하차총승객수   모기지수      검색량  \
# ...

# %%
cd_low = cd2.iloc[:42433,:]
cd_low
# Out:
#            date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 49997  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 50001  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 50000  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 49999  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 49998  20170805      8    11140     400      중구  9.1    30.1  33.125845
# ...         ...    ...      ...     ...     ...  ...     ...        ...
# 29168  20170510      5    11320    2423     도봉구  8.0    16.3  16.871285
# 29167  20170510      5    11320    2423     도봉구  8.0    16.3  16.871285
# 66647  20171019     10    11560    2423    영등포구  8.0    17.7  21.074185
# 29166  20170510      5    11320    2423     도봉구  8.0    16.3  16.871285
# 29164  20170510      5    11320    2423     도봉구  8.0    16.3  16.871285
#
#        강수량(mm)  풍속(m/s)  ...   역명   총승객수  승차총승객수  하차총승객수   모기지수      검색량  \
# ...

# %%
cd_middle = cd2.iloc[42433:-42433,:]
cd_middle
# Out:
#            date  month  gu_code  target gu_name   일교차  기온(°C)       체감온도  \
# 66638  20171019     10    11560    2423    영등포구   8.0    17.7  21.074185
# 66637  20171019     10    11560    2423    영등포구   8.0    17.7  21.074185
# 66636  20171019     10    11560    2423    영등포구   8.0    17.7  21.074185
# 66044  20171017     10    11560    2423    영등포구  11.5    17.0  19.981900
# 2620   20170112      1    11305    2423     강북구   6.5    -1.4 -21.140380
# ...         ...    ...      ...     ...     ...   ...     ...        ...
# 99217  20180306      3    11500    3612     강서구  11.5     4.2   1.173250
# 99213  20180306      3    11500    3612     강서구  11.5     4.2   1.173250
# 99214  20180306      3    11500    3612     강서구  11.5     4.2   1.173250
# 99215  20180306      3    11500    3612     강서구  11.5     4.2   1.173250
# 99218  20180306      3    11500    3612     강서구  11.5     4.2   1.173250
#
#        강수량(mm)  풍속(m/s)  ...     역명   총승객수  승차총승객수  하차총승객수  모기지수      검색량  \
# ...

# %%
cd_high = cd2.iloc[-42433:,:]
cd_high
# Out:
#            date  month  gu_code  target gu_name   일교차  기온(°C)       체감온도  \
# 99219  20180306      3    11500    3612     강서구  11.5     4.2   1.173250
# 30340  20170515      5    11440    3613     마포구   8.3    15.7   8.471690
# 70336  20171103     11    11290    3613     성북구  10.4    11.9   2.556395
# 30346  20170515      5    11440    3613     마포구   8.3    15.7   8.471690
# 30347  20170515      5    11440    3613     마포구   8.3    15.7   8.471690
# ...         ...    ...      ...     ...     ...   ...     ...        ...
# 83153  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 83152  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 83168  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 83158  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 83167  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
#
#        강수량(mm)  풍속(m/s)  ...     역명    총승객수  승차총승객수  하차총승객수   모기지수      검색량  \
# ...

# %%
cd["class"] = cd.apply(lambda x:
         0 if (x['target'] <= 2423)
         else 1
         if (x['target'] < 3613)
         else 2, axis = 1)

# %%
cd["class"].value_counts()
# Out:
# 0    42487
# 2    42432
# 1    42382
# Name: class, dtype: int64

# %%
cd
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 0       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 1       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 2       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 3       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 4       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# ...          ...    ...      ...     ...     ...  ...     ...        ...
# 127296  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127297  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127298  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127299  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127300  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
#
#         강수량(mm)  풍속(m/s)  ...    총승객수  승차총승객수  하차총승객수   모기지수      검색량     y  \
# ...

# %%
cd.to_csv("data_real_sun_hol_3class.csv", encoding = 'cp949', index = False)

# %% [markdown]
# # Real (sun, hol) : 2 class

# %%
cd = pd.read_csv("REAL_DATA_DROP_sun_hol.csv", encoding = "CP949")
cd
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 0       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 1       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 2       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 3       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 4       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# ...          ...    ...      ...     ...     ...  ...     ...        ...
# 127296  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127297  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127298  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127299  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127300  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
#
#         강수량(mm)  풍속(m/s)  ...    역명    총승객수  승차총승객수  하차총승객수   모기지수      검색량  \
# ...

# %%
127301 / 2
# Out:
# 63650.5

# %%
cd2 = cd.sort_values(by = "target")
cd2
# Out:
#            date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 49997  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 50001  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 50000  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 49999  20170805      8    11140     400      중구  9.1    30.1  33.125845
# 49998  20170805      8    11140     400      중구  9.1    30.1  33.125845
# ...         ...    ...      ...     ...     ...  ...     ...        ...
# 83153  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
# 83152  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
# 83168  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
# 83158  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
# 83167  20171226     12    11710   12482     송파구  7.6    -2.6 -23.218420
#
#        강수량(mm)  풍속(m/s)  ...     역명   총승객수  승차총승객수  하차총승객수   모기지수      검색량  \
# ...

# %%
cd_low = cd2.iloc[:63650,:]
cd_low
# Out:
#            date  month  gu_code  target gu_name   일교차  기온(°C)       체감온도  \
# 49997  20170805      8    11140     400      중구   9.1    30.1  33.125845
# 50001  20170805      8    11140     400      중구   9.1    30.1  33.125845
# 50000  20170805      8    11140     400      중구   9.1    30.1  33.125845
# 49999  20170805      8    11140     400      중구   9.1    30.1  33.125845
# 49998  20170805      8    11140     400      중구   9.1    30.1  33.125845
# ...         ...    ...      ...     ...     ...   ...     ...        ...
# 20372  20170331      3    11200    2994     성동구   5.5     9.8   4.242100
# 20373  20170331      3    11200    2994     성동구   5.5     9.8   4.242100
# 98568  20180303      3    11350    2994     노원구  19.0     7.1   8.977800
# 98565  20180303      3    11350    2994     노원구  19.0     7.1   8.977800
# 37361  20170614      6    11350    2994     노원구  14.8    21.3  22.556035
#
#        강수량(mm)  풍속(m/s)  ...    역명   총승객수  승차총승객수  하차총승객수   모기지수      검색량  \
# ...

# %%
cd_middle = cd2.iloc[-63650:]
cd_middle
# Out:
#            date  month  gu_code  target gu_name   일교차  기온(°C)       체감온도  \
# 98567  20180303      3    11350    2994     노원구  19.0     7.1   8.977800
# 13824  20170303      3    11740    2994     강동구  12.7     3.5   3.316550
# 20383  20170331      3    11200    2994     성동구   5.5     9.8   4.242100
# 37368  20170614      6    11350    2994     노원구  14.8    21.3  22.556035
# 37367  20170614      6    11350    2994     노원구  14.8    21.3  22.556035
# ...         ...    ...      ...     ...     ...   ...     ...        ...
# 83153  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 83152  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 83168  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 83158  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
# 83167  20171226     12    11710   12482     송파구   7.6    -2.6 -23.218420
#
#        강수량(mm)  풍속(m/s)  ...     역명   총승객수  승차총승객수  하차총승객수   모기지수      검색량  \
# ...

# %%
cd["class"] = cd.apply(lambda x:
         0 if (x['target'] < 2994)
         else 1, axis = 1)

# %%
cd["class"].value_counts()
# Out:
# 1    63662
# 0    63639
# Name: class, dtype: int64

# %%
cd
# Out:
#             date  month  gu_code  target gu_name  일교차  기온(°C)       체감온도  \
# 0       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 1       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 2       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 3       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# 4       20170102      1    11110    1912     종로구  6.2     4.0  -1.026800
# ...          ...    ...      ...     ...     ...  ...     ...        ...
# 127296  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127297  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127298  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127299  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
# 127300  20180630      6    11740    1985     강동구  7.3    24.3  25.966885
#
#         강수량(mm)  풍속(m/s)  ...    총승객수  승차총승객수  하차총승객수   모기지수      검색량     y  \
# ...

# %%
cd.to_csv("data_real_sun_hol_2class.csv", encoding = 'cp949', index = False)
