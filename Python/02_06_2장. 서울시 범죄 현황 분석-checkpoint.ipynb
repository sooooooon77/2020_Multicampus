# %%
#데이타 획득하기 
#서울특별시 관서별 5대 범죄 현황  https://www.data.go.kr/dataset/3075835/fileData.do
#crime (크라임)

# %%
# !conda install pandas

# %%
import pandas as pd;
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-493e06395aae> in <module>
# ----> 1 import pandas as pd;
#       2 import numpy as np
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
crime_police = pd.read_csv("data/02. crime_in_Seoul.csv", encoding="euc-kr")
crime_police
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 0    중부서      2      2      3      2    105     65  1,395    477  1,355  1,170
# 1    종로서      3      3      6      5    115     98  1,070    413  1,278  1,070
# 2   남대문서      1      0      6      4     65     46  1,153    382    869    794
# 3   서대문서      2      2      5      4    154    124  1,812    738  2,056  1,711
# 4    혜화서      3      2      5      4     96     63  1,114    424  1,015    861
# 5    용산서      5      5     14     14    194    173  1,557    587  2,050  1,704
# 6    성북서      2      2      2      1     86     71    953    409  1,194  1,015
# 7   동대문서      5      5     13     13    173    146  1,981    814  2,548  2,227
# 8    마포서      8      8     14     10    294    247  2,555    813  2,983  2,519
# 9   영등포서     14     12     22     20    295    183  2,964    978  3,572  2,961
# 10   성동서      4      4      9      8    126    119  1,607    597  1,612  1,395
# ...

# %%
#하나의 구에는  여러 관서가 있다. 같은 구의 관서의 데이타를 합쳐서 보고자한다.
#구에 위치하는 관서의 목록으로 보고자한다 
#지도의 정보를 얻어서 이를 얻어보자
#Google Map API 키받기 ..............AIzaSyC55VqabGvLBsJm12rMvfqEDJ6WJSoI5wc
#대시보드 > API서비스 사용 설정 > Geolocation API  추가 
#googlemaps설치 .....................pip install googlemaps

# %%
# !conda install googlemaps
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - googlemaps
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import googlemaps

# %%
import googlemaps
gmaps_key = "AIzaSyB0zM0_78WX7dLRIfkVoLoALZZdaALY55E"
gmaps = googlemaps.Client(key=gmaps_key)
gmaps.geocode("서울성동경찰서", language="ko") 
#'formatted_address' : 주소 
# lat : 위도
# lng : 경도
# Out:
# [{'address_components': [{'long_name': '９',
#     'short_name': '９',
#     'types': ['premise']},
#    {'long_name': '왕십리광장로',
#     'short_name': '왕십리광장로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '행당동',
#     'short_name': '행당동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '성동구',
#     'short_name': '성동구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '133-071',
#     'short_name': '133-071',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 성동구 행당동 왕십리광장로 9',
#   'geometry': {'location': {'lat': 37.5617309, 'lng': 127.0363806},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5630798802915,
# ...

# %%
#경찰서의 중보를 가져오기 위해 경찰서 이름을 변경해보자 
#성동서 -> 서울성동경찰서 
station_name=[]
for name in crime_police["관서명"]:
    station_name.append("서울" + str(name[:-1]) + "경찰서" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-feac3616d397> in <module>
#       2 #성동서 -> 서울성동경찰서
#       3 station_name=[]
# ----> 4 for name in crime_police["관서명"]:
#       5     station_name.append("서울" + str(name[:-1]) + "경찰서" )
#
# NameError: name 'crime_police' is not defined

# %%
station_name[10]
# Out:
# '서울성동경찰서'

# %%
len(station_name)
# Out:
# 31

# %%
#경찰서의 주소, 위도, 경도를 가지고 온다. 
station_address = []
station_lat=[]
station_lng=[]
for name in station_name:
    tmp = gmaps.geocode(name, language="ko")
    station_address.append(tmp[0].get("formatted_address"))
    tmp_loc = tmp[0].get("geometry")
    station_lat.append(tmp_loc["location"]["lat"]) 
    station_lng.append(tmp_loc["location"]["lng"]) 
    print(name + "-->" + tmp[0].get("formatted_address"))
# Out:
# 서울중부경찰서-->대한민국 서울특별시 중구 을지로동 수표로 27
# 서울종로경찰서-->대한민국 서울특별시 종로구 종로1.2.3.4가동 율곡로 46
# 서울남대문경찰서-->대한민국 서울특별시 중구 회현동 한강대로 410
# 서울서대문경찰서-->대한민국 서울특별시 서대문구 충현동 통일로 113
# 서울혜화경찰서-->대한민국 서울특별시 종로구 인의동 창경궁로 112-16
# 서울용산경찰서-->대한민국 서울특별시 용산구 원효로1가 백범로 329
# 서울성북경찰서-->대한민국 서울특별시 성북구 삼선동5가 301
# 서울동대문경찰서-->대한민국 서울특별시 동대문구 청량리동 약령시로21길 29
# 서울마포경찰서-->대한민국 서울특별시 마포구 아현동 618-1
# 서울영등포경찰서-->대한민국 서울특별시 영등포구 영등포동 영등포로46길 14
# 서울성동경찰서-->대한민국 서울특별시 성동구 행당동 왕십리광장로 9
# 서울동작경찰서-->대한민국 서울특별시 동작구 노량진1동 노량진로 148
# 서울광진경찰서-->대한민국 서울특별시 광진구 구의동 자양로 167
# 서울서부경찰서-->대한민국 서울특별시 은평구 대조동 통일로 757
# 서울강북경찰서-->대한민국 서울특별시 강북구 번1동 오패산로 406
# 서울금천경찰서-->대한민국 서울특별시 금천구 시흥동 190
# 서울중랑경찰서-->대한민국 서울특별시 중랑구 신내1동 신내역로3길 40-10
# 서울강남경찰서-->대한민국 서울특별시 강남구 대치동 998
# 서울관악경찰서-->대한민국 서울특별시 관악구 봉천동
# 서울강서경찰서-->대한민국 서울특별시 양천구 신월동 화곡로 73
# 서울강동경찰서-->대한민국 서울특별시 강동구 성내1동 성내로 57
# 서울종암경찰서-->대한민국 서울특별시 성북구 종암동 종암로 135
# 서울구로경찰서-->대한민국 서울특별시 구로구 가마산로 235
# 서울서초경찰서-->대한민국 서울특별시 서초구 서초3동 반포대로 179
# 서울양천경찰서-->대한민국 서울특별시 양천구 신정6동 목동동로 99
# ...

# %%
station_address[0:5]
# Out:
# ['대한민국 서울특별시 중구 을지로동 수표로 27',
#  '대한민국 서울특별시 종로구 종로1.2.3.4가동 율곡로 46',
#  '대한민국 서울특별시 중구 회현동 한강대로 410',
#  '대한민국 서울특별시 서대문구 충현동 통일로 113',
#  '대한민국 서울특별시 종로구 인의동 창경궁로 112-16']

# %%
station_lat[0:5]
# Out:
# [37.5636465, 37.5755578, 37.5547584, 37.5647848, 37.5718529]

# %%
station_lng[0:5]
# Out:
# [126.9895796, 126.9848674, 126.9734981, 126.9667762, 126.9989143]

# %%
### 주소에서 구만 뽑아오는 방법 ###

# 방법 1
a = '주소'
a.split()[2]

# 방법 2
[gu for gu in a.split() if gu[-1] == '구']   # 마지막 글자가 '구'로 오는 단어 찾기

# %%
#경찰서가 어느구 에 속하는지 칼럼을 추가하자 
gu_name = []
for name in station_address:
    tmp = name.split()
    tmp_gu = [gu for gu in tmp if  gu[-1] == "구"][0]
    gu_name.append(tmp_gu)
    
crime_police["구별"] = gu_name
crime_police
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65  1,395    477  1,355
# 1    종로서      3      3      6      5    115     98  1,070    413  1,278
# 2   남대문서      1      0      6      4     65     46  1,153    382    869
# 3   서대문서      2      2      5      4    154    124  1,812    738  2,056
# 4    혜화서      3      2      5      4     96     63  1,114    424  1,015
# 5    용산서      5      5     14     14    194    173  1,557    587  2,050
# 6    성북서      2      2      2      1     86     71    953    409  1,194
# 7   동대문서      5      5     13     13    173    146  1,981    814  2,548
# 8    마포서      8      8     14     10    294    247  2,555    813  2,983
# 9   영등포서     14     12     22     20    295    183  2,964    978  3,572
# 10   성동서      4      4      9      8    126    119  1,607    597  1,612
# 11   동작서      5      5      9      5    285    139  1,865    661  1,910
# ...

# %%
#예외
#금천경찰서는 관악구 ------------서울특별시 관악구 신림동 남부순환로 1435
crime_police[crime_police["관서명"] == "금천서"]
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거  \
# 15  금천서      3      4      6      6    151    122  1,567   888  2,054  1,776
#
#      구별
# 15  금천구

# %%
s="aa"
t="bb"
s+t
# Out:
# 'aabb'

# %%
#df = crime_police[["관서명", "구별"]]
s1 = list(crime_police["관서명"])
s2 = list(crime_police["구별"])
mylist = list(zip(crime_police["관서명"], crime_police["구별"]))
mylist
# Out:
# [('중부서', '중구'),
#  ('종로서', '종로구'),
#  ('남대문서', '중구'),
#  ('서대문서', '서대문구'),
#  ('혜화서', '종로구'),
#  ('용산서', '용산구'),
#  ('성북서', '성북구'),
#  ('동대문서', '동대문구'),
#  ('마포서', '마포구'),
#  ('영등포서', '영등포구'),
#  ('성동서', '성동구'),
#  ('동작서', '동작구'),
#  ('광진서', '광진구'),
#  ('서부서', '은평구'),
#  ('강북서', '강북구'),
#  ('금천서', '금천구'),
#  ('중랑서', '중랑구'),
#  ('강남서', '강남구'),
#  ('관악서', '관악구'),
#  ('강서서', '양천구'),
#  ('강동서', '강동구'),
#  ('종암서', '성북구'),
#  ('구로서', '구로구'),
#  ('서초서', '서초구'),
#  ('양천서', '양천구'),
#  ('송파서', '송파구'),
#  ('노원서', '노원구'),
#  ('방배서', '서초구'),
#  ('은평서', '은평구'),
#  ('도봉서', '도봉구'),
#  ('수서서', '강남구')]

# %%
crime_police.to_csv("./data/crime_guname_jj.csv")

# %% [markdown]
# # Pandas의 pivot_table 학습학기

# %%
import pandas as pd;
import numpy as np;
import openpyxl

# %%
import pandas as pd;
import numpy as np;
df = pd.read_excel("data/salesfunnel.xlsx")
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
#Name칼럼이 index가 되고 숫자형 칼럼들이 남는다. 
pd.pivot_table(df, index=["Name"])    ## name에 따른 각 컬럼의 평균이 나타남
# Out:
#                                Account     Price  Quantity
# Name
# Barton LLC                    740150.0   35000.0  1.000000
# Fritsch, Russel and Anderson  737550.0   35000.0  1.000000
# Herman LLC                    141962.0   65000.0  2.000000
# Jerde-Hilpert                 412290.0    5000.0  2.000000
# Kassulke, Ondricka and Metz   307599.0    7000.0  3.000000
# Keeling LLC                   688981.0  100000.0  5.000000
# Kiehn-Spinka                  146832.0   65000.0  2.000000
# Koepp Ltd                     729833.0   35000.0  2.000000
# Kulas Inc                     218895.0   25000.0  1.500000
# Purdy-Kunde                   163416.0   30000.0  1.000000
# Stokes LLC                    239344.0    7500.0  1.000000
# Trantow-Barrows               714466.0   15000.0  1.333333

# %%
#"Name","Rep","Manager"칼럼이 index가 되고 숫자형 칼럼들이 남는다.
pd.pivot_table(df, index=["Name","Rep","Manager"])
# Out:
#                                                            Account     Price  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley   740150.0   35000.0
# Fritsch, Russel and Anderson Craig Booker  Debra Henley   737550.0   35000.0
# Herman LLC                   Cedric Moss   Fred Anderson  141962.0   65000.0
# Jerde-Hilpert                John Smith    Debra Henley   412290.0    5000.0
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson  307599.0    7000.0
# Keeling LLC                  Wendy Yule    Fred Anderson  688981.0  100000.0
# Kiehn-Spinka                 Daniel Hilton Debra Henley   146832.0   65000.0
# Koepp Ltd                    Wendy Yule    Fred Anderson  729833.0   35000.0
# Kulas Inc                    Daniel Hilton Debra Henley   218895.0   25000.0
# Purdy-Kunde                  Cedric Moss   Fred Anderson  163416.0   30000.0
# ...

# %%
 #pivot테이블로 합친경우 평균치가 기본이 된다. 
pd.pivot_table(df, index=["Manager","Rep"], values=["Price"])
# Out:
#                                     Price
# Manager       Rep
# Debra Henley  Craig Booker   20000.000000
#               Daniel Hilton  38333.333333
#               John Smith     20000.000000
# Fred Anderson Cedric Moss    27500.000000
#               Wendy Yule     44250.000000

# %% [markdown]
# => manager, rep에 따른 price 평균을 보여줌  =>  밑에서 확인

# %%
df[(df.Manager == 'Debra Henley') & (df.Rep == 'Craig Booker')]["Price"].mean()
# Out:
# 20000.0

# %%
 #pivot테이블에 mean을 보여주기  
pd.pivot_table(df, index=["Manager","Rep"], values=["Price"], aggfunc=np.mean)
# Out:
#                                     Price
# Manager       Rep
# Debra Henley  Craig Booker   20000.000000
#               Daniel Hilton  38333.333333
#               John Smith     20000.000000
# Fred Anderson Cedric Moss    27500.000000
#               Wendy Yule     44250.000000

# %%
 #pivot테이블에 sum을 보여주기  
pd.pivot_table(df, index=["Manager","Rep"], values=["Price"], aggfunc=np.sum)
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    80000
#               Daniel Hilton  115000
#               John Smith      40000
# Fred Anderson Cedric Moss    110000
#               Wendy Yule     177000

# %%
#sum과 mean을 모두 출력하기 
#fill_value=0 의미는 NaN을 0으로 처리처리하겠다는 의미이다. 
#margins=True의 의미는 행과 열의 합계를 추가한다. 
pd.pivot_table(df, index=["Manager","Rep","Product"], values=["Price","Quantity"], 
               aggfunc=[np.sum, np.mean], fill_value=0,margins=True)
# Out:
#                                             sum            mean
#                                           Price Quantity  Price  Quantity
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000        2  32500  1.000000
#                             Maintenance    5000        2   5000  2.000000
#                             Software      10000        1  10000  1.000000
#               Daniel Hilton CPU          105000        4  52500  2.000000
#                             Software      10000        1  10000  1.000000
#               John Smith    CPU           35000        1  35000  1.000000
#                             Maintenance    5000        2   5000  2.000000
# Fred Anderson Cedric Moss   CPU           95000        3  47500  1.500000
#                             Maintenance    5000        1   5000  1.000000
#                             Software      10000        1  10000  1.000000
# ...

# %% [markdown]
# ## 3 Pivot_table을 이용해서 데이터 정리하기

# %%
crime_anal_raw = pd.read_csv("data/02. crime_in_Seoul_include_gu_name.csv", encoding="utf-8")
crime_anal_raw
# Out:
#     Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0            0   중부서      2      2      3      2    105     65   1395    477
# 1            1   종로서      3      3      6      5    115     98   1070    413
# 2            2  남대문서      1      0      6      4     65     46   1153    382
# 3            3  서대문서      2      2      5      4    154    124   1812    738
# 4            4   혜화서      3      2      5      4     96     63   1114    424
# 5            5   용산서      5      5     14     14    194    173   1557    587
# 6            6   성북서      2      2      2      1     86     71    953    409
# 7            7  동대문서      5      5     13     13    173    146   1981    814
# 8            8   마포서      8      8     14     10    294    247   2555    813
# 9            9  영등포서     14     12     22     20    295    183   2964    978
# 10          10   성동서      4      4      9      8    126    119   1607    597
# ...

# %%
#구별합계구하기 
crime_anal = pd.pivot_table(crime_anal_raw, index="구별", aggfunc=np.sum)
len(crime_anal)
# Out:
# 24

# %%
crime_anal.head(2)
# Out:
#      Unnamed: 0  강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  \
# 구별
# 강남구          47    349    449     18     21     10     13   1650   3850
# 강동구          20    123    156      8      6      3      4    789   2366
#
#      폭력 검거  폭력 발생
# 구별
# 강남구   3705   4284
# 강동구   2248   2712

# %%
crime_anal["강간검거율"] = crime_anal["강간 검거"] / crime_anal["강간 발생"] * 100
crime_anal["강도검거율"] = crime_anal["강도 검거"] / crime_anal["강도 발생"] * 100
crime_anal["살인검거율"] = crime_anal["살인 검거"] / crime_anal["살인 발생"] * 100
crime_anal["폭력검거율"] = crime_anal["폭력 검거"] / crime_anal["폭력 발생"] * 100
crime_anal["절도검거율"] = crime_anal["절도 검거"] / crime_anal["절도 발생"] * 100
del crime_anal["강간 검거"]
del crime_anal["강도 검거"]
del crime_anal["살인 검거"]
del crime_anal["폭력 검거"]
del crime_anal["절도 검거"]
crime_anal.head()
# Out:
#      Unnamed: 0  강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율  \
# 구별
# 강남구          47    449     21     13   3850   4284  77.728285   85.714286
# 강동구          20    156      6      4   2366   2712  78.846154  133.333333
# 강북구          14    153     14      7   1434   2649  82.352941   92.857143
# 관악구          18    320     12      9   2706   3298  69.062500  116.666667
# 광진구          12    240     14      4   3026   2625  91.666667  185.714286
#
#           살인검거율      폭력검거율      절도검거율
# 구별
# 강남구   76.923077  86.484594  42.857143
# 강동구   75.000000  82.890855  33.347422
# 강북구  114.285714  88.637222  43.096234
# 관악구   88.888889  80.109157  30.561715
# 광진구  100.000000  83.047619  42.200925

# %%
crime_anal.columns
# Out:
# Index(['Unnamed: 0', '강간 발생', '강도 발생', '살인 발생', '절도 발생', '폭력 발생', '강간검거율',
#        '강도검거율', '살인검거율', '폭력검거율', '절도검거율'],
#       dtype='object')

# %%
del crime_anal["Unnamed: 0"]

# %%
crime_anal.columns
# Out:
# Index(['강간 발생', '강도 발생', '살인 발생', '절도 발생', '폭력 발생', '강간검거율', '강도검거율', '살인검거율',
#        '폭력검거율', '절도검거율'],
#       dtype='object')

# %%
#검거율이 100이상인 것은? 100으로 처리 
con_list = ['강간검거율', '강도검거율', '살인검거율','폭력검거율', '절도검거율']
for column in con_list:
    crime_anal.loc[crime_anal[column]>100, column] = 100
crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  100.000000   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  100.000000
# 관악구    320     12      9   2706   3298  69.062500  100.000000   88.888889
# 광진구    240     14      4   3026   2625  91.666667  100.000000  100.000000
#
#          폭력검거율      절도검거율
# 구별
# 강남구  86.484594  42.857143
# 강동구  82.890855  33.347422
# 강북구  88.637222  43.096234
# 관악구  80.109157  30.561715
# 광진구  83.047619  42.200925

# %%
#칼럼이름을 변경하자 
#구별 5대 범죄발생 건수와 검거율 데이터로 정리됨 
cols = {}
for i in crime_anal.columns:
    if "발생" in i:
        cols[i] =  i[0:2]
crime_anal.rename(columns=cols, inplace=True)
crime_anal.head(2)


# crime_anal.rename(columns={'강간 발생':"강간", '강도 발생':"강도", '살인 발생':"살인",'폭력 발생':"폭력", '절도 발생':"절도"},
#                   inplace=True)
# Out:
#       강간  강도  살인    절도    폭력      강간검거율       강도검거율      살인검거율      폭력검거율  \
# 구별
# 강남구  449  21  13  3850  4284  77.728285   85.714286  76.923077  86.484594
# 강동구  156   6   4  2366  2712  78.846154  100.000000  75.000000  82.890855
#
#          절도검거율
# 구별
# 강남구  42.857143
# 강동구  33.347422

# %% [markdown]
# ## 각 칼럼별 정규화

# %%
#데이터 표현 다듬기...강도와 살인은 2자리인데 절도와 폭력은 4자리이다. 
#각각을 비슷한 범위에 두고 비교하는 것이 편리하다.
#각 항목의 최대값을 1로 두면 추후 범죄발생 건수를 종합적으로 비교할 때 편리한다. ...각 칼럼별 정규화

# %%
col = ["강간","강도","살인","절도","폭력"]
x = crime_anal[col].values
x
# Out:
# array([[ 449,   21,   13, 3850, 4284],
#        [ 156,    6,    4, 2366, 2712],
#        [ 153,   14,    7, 1434, 2649],
#        [ 320,   12,    9, 2706, 3298],
#        [ 240,   14,    4, 3026, 2625],
#        [ 281,   15,    8, 2335, 3007],
#        [ 151,    6,    3, 1567, 2054],
#        [ 197,    7,   10, 2193, 2723],
#        [ 102,    9,    3, 1063, 1487],
#        [ 173,   13,    5, 1981, 2548],
#        [ 285,    9,    5, 1865, 1910],
#        [ 294,   14,    8, 2555, 2983],
#        [ 154,    5,    2, 1812, 2056],
#        [ 393,    9,    8, 2635, 2399],
#        [ 126,    9,    4, 1607, 1612],
#        [ 150,    5,    5, 1785, 2209],
#        [ 220,   13,   11, 3239, 3295],
#        [ 382,   19,   10, 3986, 5716],
#        [ 295,   22,   14, 2964, 3572],
#        [ 194,   14,    5, 1557, 2050],
#        [ 166,    9,    3, 1914, 2653],
#        [ 211,   11,    6, 2184, 2293],
#        [ 170,    9,    3, 2548, 2224],
#        [ 187,   11,   13, 2135, 2847]], dtype=int64)

# %%
from sklearn import  preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x.astype(float))
x_scaled
# Out:
# array([[1.        , 0.94117647, 0.91666667, 0.95347246, 0.66138567],
#        [0.1556196 , 0.05882353, 0.16666667, 0.44577489, 0.28966659],
#        [0.14697406, 0.52941176, 0.41666667, 0.12692439, 0.27476945],
#        [0.62824207, 0.41176471, 0.58333333, 0.56209374, 0.42823362],
#        [0.39769452, 0.52941176, 0.16666667, 0.6715703 , 0.26909435],
#        [0.51585014, 0.58823529, 0.5       , 0.43516935, 0.35942303],
#        [0.14121037, 0.05882353, 0.08333333, 0.17242559, 0.13407425],
#        [0.27377522, 0.11764706, 0.66666667, 0.38658912, 0.29226768],
#        [0.        , 0.23529412, 0.08333333, 0.        , 0.        ],
#        [0.20461095, 0.47058824, 0.25      , 0.3140609 , 0.25088673],
#        [0.52737752, 0.23529412, 0.25      , 0.27437564, 0.10002365],
#        [0.55331412, 0.52941176, 0.5       , 0.51043449, 0.35374793],
#        [0.14985591, 0.        , 0.        , 0.25624359, 0.13454717],
#        [0.83861671, 0.23529412, 0.5       , 0.53780363, 0.21565382],
# ...

# %%
crime_anal_norm = pd.DataFrame(x_scaled, columns=col, index=crime_anal.index)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094

# %%
col2 = ["강간검거율","강도검거율","살인검거율","절도검거율","폭력검거율"]
crime_anal_norm[col2] = crime_anal[col2]
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  100.000000  43.096234  88.637222
# 관악구   88.888889  30.561715  80.109157
# 광진구  100.000000  42.200925  83.047619

# %% [markdown]
# # 범죄검거율과 CCTVV가 상관이 있을까?

# %%
result_cctv = pd.read_csv("./data/01. CCTV_result.csv", encoding="utf-8", index_col="구별")
result_cctv.head(2)
# Out:
#        소계       최근증가율       인구수       한국인     외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0  4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0  4214.0  54622.0  0.929765
#
#          고령자비율    CCTV비율           오차
# 구별
# 강남구  11.072217  0.487292  1388.055355
# 강동구  12.051638  0.170552   465.422892

# %%
cctv_df = result_cctv[["인구수","소계"]]
cctv_df.head(2)
# Out:
#           인구수    소계
# 구별
# 강남구  570500.0  2780
# 강동구  453233.0   773

# %%
#칼럼이 잘못들어갔다면 지운다. 
crime_anal_norm.drop(["인구수", "소계"], inplace=True, axis=1)

# %%
crime_anal_norm.head(2)
# Out:
#           강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.00000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.15562  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
#
#          살인검거율      절도검거율      폭력검거율
# 구별
# 강남구  76.923077  42.857143  86.484594
# 강동구  75.000000  33.347422  82.890855

# %%
crime_anal_norm = pd.merge(crime_anal_norm, cctv_df, on="구별")
crime_anal_norm.head(2)
# Out:
#           강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.00000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.15562  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
#
#          살인검거율      절도검거율      폭력검거율       인구수    소계
# 구별
# 강남구  76.923077  42.857143  86.484594  570500.0  2780
# 강동구  75.000000  33.347422  82.890855  453233.0   773

# %%
#칼럼이름을 변경하자   "소계"=>"CCTV"
crime_anal_norm.rename(columns={"소계":"CCTV" }, inplace=True)
crime_anal_norm.head(2)
# Out:
#           강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.00000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.15562  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
#
#          살인검거율      절도검거율      폭력검거율       인구수  CCTV
# 구별
# 강남구  76.923077  42.857143  86.484594  570500.0  2780
# 강동구  75.000000  33.347422  82.890855  453233.0   773

# %%
#5대 범죄의 합계를 칼럼으로 추가한다. 
col = ["강간","강도","살인","절도","폭력"]
crime_anal_norm["범죄"] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780  4.472701
# 강동구   75.000000  33.347422  82.890855  453233.0   773  1.116551
# 강북구  100.000000  43.096234  88.637222  330192.0   748  1.494746
# 관악구   88.888889  30.561715  80.109157  525515.0  1496  2.613667
# 광진구  100.000000  42.200925  83.047619  372164.0   707  2.034438

# %%
#검거울의 합계를 칼럼으로 추가한다. 
col = ["강간검거율","강도검거율","살인검거율","절도검거율","폭력검거율"]
crime_anal_norm["검거"] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄          검거
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780  4.472701  369.707384
# 강동구   75.000000  33.347422  82.890855  453233.0   773  1.116551  370.084431
# 강북구  100.000000  43.096234  88.637222  330192.0   748  1.494746  406.943540
# 관악구   88.888889  30.561715  80.109157  525515.0  1496  2.613667  368.622261
# 광진구  100.000000  42.200925  83.047619  372164.0   707  2.034438  416.915211

# %% [markdown]
# # seaborn으로 시각화하기

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
x = np.linspace(0, 14,100)
y1 = np.sin(x)
y2 = 2*np.sin(x+0.5)
y3 = 3*np.sin(x+1.0)
y4 = 4*np.sin(x+1.5)

plt.figure(figsize=(10,6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
#seaborn은 연습할 데이터셋도 가지고 있다.
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#요일별 식사금액
plt.figure(figsize=(10,6))
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
#hue : 흡연여부로 결재금액의 차이를 볼 수 있다. ....흡연자가 결재금액이 크네요

plt.figure(figsize=(10,6))
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="Set3")
plt.show()

# %%
#hue : 남자가 결재금액이 크네요

plt.figure(figsize=(10,6))
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips, palette="Set3")
plt.show()

# %%
#결재금액과 팁의 상관관계를 그려본다. ~~~~상관이 있음을 볼 수 있다....결재금액이 많을수록 팁이 많아짐 
sns.set_style("darkgrid")
sns.lmplot(x="total_bill",y="tip", data=tips)
plt.show()

# %%
#흡연여부와 같이보기 
sns.lmplot(x="total_bill",y="tip", hue="smoker", data=tips )
plt.show()

# %%
flights = sns.load_dataset("flights")
flights.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot("month","year","passengers")
flights.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
plt.figure(figsize=(10,8))
sns.heatmap(flights, annot=True, fmt="d") #annot=True는 숫자를 보여줌을 의미 
plt.show()

# %%
sns.set(style="ticks")
iris = sns.load_dataset("iris")
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
#붓꽃의  (sepal_length,sepal_width,petal_length,petal_width) 칼럼정보에 의한 종을 분류   
sns.pairplot(iris, hue="species"  )
plt.show()

# %% [markdown]
# # 범죄데이타시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import platform
from matplotlib import font_manager, rc
path="c:/Windows/Fonts/malgun.ttf"

if platform.system() =="Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc("font", family=font_name)

# %%
sns.pairplot(crime_anal_norm, vars=["강도","살인","폭력"], kind="reg" )
plt.show()
#강도와 살인, 살인과 폭력, 강도와 살인  모두 양의 상관관계가 보인다.

# %%
sns.pairplot(crime_anal_norm, x_vars=["인구수","CCTV"], y_vars=["살인", "강도"], kind="reg" )
plt.show()
#CCTV와 살인의 관계는 낮지만 CCTV가 없을 때 살인이 많이 일어나는 구간이 있다.

# %%
sns.pairplot(crime_anal_norm, x_vars=["인구수","CCTV"], y_vars=["살인검거율","폭력검거율"], kind="reg")
plt.show()
#양의상관관계가 아니다. 오히려 음의 상관관계도 보인다.

# %%
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄          검거
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780  4.472701  369.707384
# 강동구   75.000000  33.347422  82.890855  453233.0   773  1.116551  370.084431
# 강북구  100.000000  43.096234  88.637222  330192.0   748  1.494746  406.943540
# 관악구   88.888889  30.561715  80.109157  525515.0  1496  2.613667  368.622261
# 광진구  100.000000  42.200925  83.047619  372164.0   707  2.034438  416.915211

# %%
#검거 황목 최고값을 100으로 한정하고 그 값으로 정렬 
tmp_max = crime_anal_norm["검거"].max()
crime_anal_norm["검거"] = crime_anal_norm["검거"] / tmp_max * 100
crime_anal_norm_sort = crime_anal_norm.sort_values(by="검거", ascending=False)
crime_anal_norm_sort.head()
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  강도검거율  \
# 구별
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000  100.0
# 금천구   0.141210  0.058824  0.083333  0.172426  0.134074   80.794702  100.0
# 광진구   0.397695  0.529412  0.166667  0.671570  0.269094   91.666667  100.0
# 동대문구  0.204611  0.470588  0.250000  0.314061  0.250887   84.393064  100.0
# 용산구   0.265130  0.529412  0.250000  0.169004  0.133128   89.175258  100.0
#
#       살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄          검거
# 구별
# 도봉구   100.0  44.967074  87.626093  348646.0   485  0.318627  100.000000
# 금천구   100.0  56.668794  86.465433  255082.0  1015  0.589867   97.997139
# 광진구   100.0  42.200925  83.047619  372164.0   707  2.034438   96.375820
# 동대문구  100.0  41.090358  87.401884  369496.0  1294  1.490147   95.444250
# 용산구   100.0  37.700706  83.121951  244203.0  1624  1.346674   94.776790

# %%
target_col = ["강간검거율","강도검거율", "살인검거율","절도검거율","폭력검거율"]
crime_anal_norm_sort = crime_anal_norm.sort_values(by="검거", ascending=False)
plt.figure(figsize=(10,10))

#각 셀의 값을 표시할지 : annot=True
# 숫자 표시를 어떻게 할지 : fmt='f'
sns.heatmap(crime_anal_norm_sort[target_col], annot=True, fmt='f', linewidths=0.5)
plt.title("범죄 검거 비율(정규화된 검거의 합으로 정렬)")
plt.show()

# %% [markdown]
# # 지도 시각화도구 Folium

# %%
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-173c1173bf1c> in <module>
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'

# %%
map_osm =folium.Map(location=[37.566345, 126.977893], zoom_start=17, tiles="Stamen Toner")  #zoom_start:초기 화면의 크기를 확대
#지도의 타입은 스테이먼 토너 
## ‘Stamen Terrain’, ‘Stamen Toner’ 형식을 내장하고 있다.
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map2 =folium.Map(location=[45.5236, -122.6750], zoom_start=13, tiles="Stamen Toner") #스테이먼 토너 (SOURCE :스테이먼 , 맵타입:토너)
folium.Marker([45.5244, -122.6699], popup="The WaterFront").add_to(map2)
folium.CircleMarker([45.5215,-122.6261], radius=50, popup="AA Park" , color="#3186cc", fill_color="#3186cc",).add_to(map2)
map2
#radius : 반경
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
state_unemployment = "data/02. folium_US_Unemployment_Oct2012.csv"  #미국의 주별 실업율 
state_data = pd.read_csv(state_unemployment)
state_data.head() ##49건있음
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
#주별  고유id, 주이름, 좌표 
state_geo = "data/02. folium_us-states.json"
state_geo_data = pd.read_json(state_geo)
state_geo_data.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'id': 'AL', 'properties': ...
# 1  FeatureCollection  {'type': 'Feature', 'id': 'AK', 'properties': ...
# 2  FeatureCollection  {'type': 'Feature', 'id': 'AZ', 'properties': ...
# 3  FeatureCollection  {'type': 'Feature', 'id': 'AR', 'properties': ...
# 4  FeatureCollection  {'type': 'Feature', 'id': 'CA', 'properties': ...

# %%
import warnings
warnings.filterwarnings("ignore")

map3=  folium.Map(location=[40,-98], zoom_start=4)
map3.choropleth(geo_data = state_geo, data=state_data,
                columns=["State","Unemployment"],
                key_on="id",
                fill_color="YlGn",
               legend_name="실업률(%)")
map3

# key_on는 지도의 id ... id가 중복되지 않아야한다. 
#choropleth : 초로플레스 .......
#음영 또는 색상의 등급차 또는 해당 영역의 일부 속성 또는 수량의 평균 값을 나타 내기 위해 맵의 정의된 영역 내부에 기호를 배치하는 맵
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 서울시 범죄율에 대한 지도 시각화

# %%
import json

# %%
geo_path = "data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding="utf-8"))
geo_str
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '강동구',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.11519584981606, 37.557533180704915],
#       [127.16683184366129, 37.57672487388627],
#       [127.18408792330152, 37.55814280369575],
#       [127.16530984307447, 37.54221851258693],
#       [127.14672806823502, 37.51415680680291],
#       [127.12123165719615, 37.52528270089],
#       [127.1116764203608, 37.540669955324965],
#       [127.11519584981606, 37.557533180704915]]]}},
#   {'type': 'Feature',
#    'id': '송파구',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0690698130372, 37.522279423505026],
#       [127.10087519791962, 37.524841220167055],
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

map4 = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="stamen Toner")
map4.choropleth(geo_data=geo_str, data=crime_anal_norm["살인"],
               columns=[crime_anal_norm.index, crime_anal_norm["살인"]],
               fill_color="PuRd",
               key_on="id")
map4
#강남3구는  안전하지않다
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map4 = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="stamen Toner")
map4.choropleth(geo_data=geo_str, data=crime_anal_norm["강간"],
               columns=[crime_anal_norm.index, crime_anal_norm["강간"]],
               fill_color="YlGnBu",
               key_on="id")
map4
#강남3구는  안전하지않다
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map4 = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="stamen Toner")
map4.choropleth(geo_data=geo_str, data=crime_anal_norm["범죄"],
               columns=[crime_anal_norm.index, crime_anal_norm["범죄"]],
               fill_color="PuRd",
               key_on="id")
map4
#강남3구는  안전하지않다
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#인구대비 범죄발생 비율
tmp_criminal = crime_anal_norm["살인"] / crime_anal_norm["인구수"] * 1000000

map4 = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="stamen Toner")
map4.choropleth(geo_data=geo_str, data=tmp_criminal,
               columns=[crime_anal_norm.index, tmp_criminal],
               fill_color="PuRd",
               key_on="id")
map4
#강남3구는  안전하지않다
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 인구대비 범죄발생 건수로보면 강남3구가 1위는 아니지만 안전도가 제일 높다고 말할 수는 없습니다.

# %% [markdown]
# # 서울시 경찰서별 검거율과 구별 범죄 발생율을 동시에 시각화하기

# %%
#station_lat , station_lng
crime_anal_raw.head()
# Out:
#    Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0           0   중부서      2      2      3      2    105     65   1395    477
# 1           1   종로서      3      3      6      5    115     98   1070    413
# 2           2  남대문서      1      0      6      4     65     46   1153    382
# 3           3  서대문서      2      2      5      4    154    124   1812    738
# 4           4   혜화서      3      2      5      4     96     63   1114    424
#
#    폭력 발생  폭력 검거    구별
# 0   1355   1170    중구
# 1   1278   1070   종로구
# 2    869    794    중구
# 3   2056   1711  서대문구
# 4   1015    861   종로구

# %%
crime_anal_raw["lat"] = station_lat
crime_anal_raw["lng"] = station_lng
col = ["살인 검거","강도 검거","강간 검거","절도 검거","폭력 검거"]
tmp = crime_anal_raw[col] / crime_anal_raw[col].max()
crime_anal_raw["검거"] = np.sum(tmp, axis=1)
print(tmp.head())
crime_anal_raw.head()
# Out:
#       살인 검거     강도 검거     강간 검거     절도 검거     폭력 검거
# 0  0.166667  0.076923  0.263158  0.373532  0.395137
# 1  0.250000  0.192308  0.396761  0.323414  0.361364
# 2  0.000000  0.153846  0.186235  0.299139  0.268153
# 3  0.166667  0.153846  0.502024  0.577917  0.577845
# 4  0.166667  0.153846  0.255061  0.332028  0.290780
#    Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0           0   중부서      2      2      3      2    105     65   1395    477
# 1           1   종로서      3      3      6      5    115     98   1070    413
# 2           2  남대문서      1      0      6      4     65     46   1153    382
# 3           3  서대문서      2      2      5      4    154    124   1812    738
# 4           4   혜화서      3      2      5      4     96     63   1114    424
#
#    폭력 발생  폭력 검거    구별        lat         lng        검거
# 0   1355   1170    중구  37.563646  126.989580  1.275416
# 1   1278   1070   종로구  37.575558  126.984867  1.523847
# ...

# %%
#경찰서의 위치 
map5 = folium.Map(location=[37.5502, 126.982], zoom_start=11)
for n in crime_anal_raw.index:
    folium.Marker([crime_anal_raw["lat"][n], crime_anal_raw["lng"][n]]).add_to(map5)
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#경찰서의 위치에서 원의 크기가 크면 검거율이 높다 
map5 = folium.Map(location=[37.5502, 126.982], zoom_start=11)
for n in crime_anal_raw.index:
    folium.CircleMarker([crime_anal_raw["lat"][n], crime_anal_raw["lng"][n]],
                       radius=crime_anal_raw["검거"][n]*10,
                       color="#3186cc", fill_color="#3186cc").add_to(map5)
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#경찰서의 위치에서 원의 크기가 크면 검거율이 높다 ,.......범죄발생건수 추가하기 
map5 = folium.Map(location=[37.5502, 126.982], zoom_start=11)

map5.choropleth(geo_data=geo_str,
               data=crime_anal_norm["범죄"],
               columns=[crime_anal_norm.index, crime_anal_norm["범죄"]],
               fill_color="PuRd",
               key_on="id")

for n in crime_anal_raw.index:
    folium.CircleMarker([crime_anal_raw["lat"][n], crime_anal_raw["lng"][n]],
                       radius=crime_anal_raw["검거"][n]*10,
                       color="#3186cc", fill_color="#3186cc").add_to(map5)
map5

#범죄가 많이 일어날수록 붉은색
#검거율이 높을수록 큰원
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
